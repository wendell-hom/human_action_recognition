# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID";  # The GPU id to use, usually either "0" or "1";
os.environ["CUDA_VISIBLE_DEVICES"]="0";  # Do other imports now...

import tensorflow as tf

# Need to specify the memory_limit for my local machine for some reason, but didn't seem to be required
# on AWS machine
gpus = tf.config.experimental.list_physical_devices('GPU')

print(gpus)
tf.config.experimental.set_virtual_device_configuration(gpus[0], [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=23400)])

# Check tensorflow version
print("Using Tensorflow %s\n" % (tf.__version__))

# Check to see if graphics card is doing OK memory-wise
# !nvidia-smi
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Using Tensorflow 2.0.0
#
# Thu Mar  5 09:16:00 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.59       Driver Version: 440.59       CUDA Version: 10.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  TITAN RTX           Off  | 00000000:08:00.0 Off |                  N/A |
# | 41%   36C    P8     5W / 280W |     12MiB / 24220MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   1  GeForce RTX 207...  Off  | 00000000:43:00.0  On |                  N/A |
# | 41%   26C    P8     1W / 215W |    625MiB /  7974MiB |     16%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |    1      1940      G   /usr/lib/xorg/Xorg                            40MiB |
# |    1      2124      G   /usr/bin/gnome-shell                          14MiB |
# |    1      3550      G   /usr/lib/xorg/Xorg                           306MiB |
# |    1      3648      G   /usr/bin/gnome-shell                         260MiB |
# +-----------------------------------------------------------------------------+

# %%
from tensorflow.keras.models import load_model
from collections import deque
import numpy as np
import cv2
from tensorflow.keras.models import Model


from tensorflow.keras.applications.inception_resnet_v2 import InceptionResNetV2, preprocess_input

model =load_model('models/class_only_30_epochs.h5')

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_resnet_v2 (Model)  (None, 17, 17, 1536)      54336736
# _________________________________________________________________
# ClassConv (Conv2D)           (None, 17, 17, 1024)      14156800
# _________________________________________________________________
# GAP (GlobalAveragePooling2D) (None, 1024)              0
# _________________________________________________________________
# class (Dense)                (None, 40)                41000
# =================================================================
# Total params: 68,534,536
# Trainable params: 14,197,800
# Non-trainable params: 54,336,736
# _________________________________________________________________

# %%
pixels = model.input.get_shape().as_list()[1]
pixels
# Out:
# 600

# %%
import json

# Read mapping file from  class index -> activity
with open("classes.json") as fp:
    mapping = json.loads(fp.read())

# Convert keys back to integer
mapping = {int(k):v for k,v in mapping.items()}

# Print out first 10 entries of mapping dictionary
for i in list(mapping)[0:10]:
    print (f"{i} : {mapping[i]}")
# Out:
# 0 : applauding
# 1 : blowing_bubbles
# 2 : brushing_teeth
# 3 : cleaning_the_floor
# 4 : climbing
# 5 : cooking
# 6 : cutting_trees
# 7 : cutting_vegetables
# 8 : drinking
# 9 : feeding_a_horse

# %%
from tensorflow.keras.applications.inception_resnet_v2 import InceptionResNetV2, preprocess_input

def predict(image_data, model):
    
    processed_input = preprocess_input(image_data)
    
    # Run model's prediction to output from last Conv Layer + category prediction
    pred_vec = model.predict(processed_input)
    
    predictions = []
    for i in range(pred_vec.shape[0]):
        predictions.append(pred_vec[i])
        
    return predictions

# %%
def predict_video(filename, k = 200):
    vs = cv2.VideoCapture(filename)

    (W, H) = (None, None)

    count = 0


    image_data = np.zeros((k, pixels, pixels, 3))

    all_predictions = []


    while True:
        
        (grabbed, frame) = vs.read()
        
        if not grabbed:
            break

        if W is None or H is None:
            (H, W) = frame.shape[:2]

        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        frame = cv2.resize(frame, (pixels, pixels)).astype("float32")
      
        
        image_data[count] = frame

        count = count + 1    
        
        if count == k:
            predictions = predict(image_data, model)
            all_predictions.extend(predictions)
            count = 0
                
    if count > 0:
        predictions = predict(image_data[:count], model)
        all_predictions.extend(predictions)
        

    vs.release()
    cv2.destroyAllWindows()

    averaged = np.mean(all_predictions, axis= 0)
    activity = mapping[np.argmax(averaged)]
    
    top_5_idx = np.argsort(averaged)[-5:]
    top_5 = [mapping[idx] for idx in top_5_idx]

    # Need to delete this otherwise we have a memory leak.
    # for some reason this isn't cleaned up automatically and kernel will die after
    # running many predictions
    for prediction in all_predictions:
        del prediction
    
    return activity, top_5

# %%
activity, top_5 = predict_video("videos/test/riding a bike/13.mp4")
activity
# Out:
# 'riding_a_bike'

# %% [markdown]
# ## Measure Accuracy of using video classification

# %%
import os
import json

correct = dict()
in_top_5 = dict()
incorrect = dict()

## The category names used in Kinetics-400 is slightly different from
## the ones used in Stanford40
category_mapping = {
    "cleaning_floor" : "cleaning_the_floor",
    "drinking_beer"  : "drinking",
    "pushing_cart"   : "pushing_a_cart",
    "reading_book"   : "reading",
    "riding_or_walking_with_horse" : "riding_a_horse",
    "texting"        : "texting_message",
    "using_computer" : "using_a_computer"
}
    
    
## Simple method to categorize videos one at a time.
## Would be nice to enhance this to run in parallel to reduce runtime
count = 0
import gc
gc.collect()

for root, dirs, files in os.walk("videos/test/"):
    for file in files:
        if file.endswith(".mp4"):
            orig_category = os.path.basename(root).replace(" ", "_")
            category = orig_category
            if category in category_mapping:
                category = category_mapping[category]
                
            prediction, top_5 = predict_video(os.path.join(root, file))
            
            if prediction == category:
                correct[os.path.join(orig_category, file)] = prediction
                print(f"correct: {os.path.join(orig_category, file)} => {prediction}")
            else:
                if category in top_5:
                    in_top_5[os.path.join(orig_category, file)] = top_5
                    print(f"in top 5: {os.path.join(orig_category, file)} => {top_5}")
                else:
                    incorrect[os.path.join(orig_category, file)] = prediction    
                    print(f"wrong: {os.path.join(orig_category, file)} => {prediction}")
                    
            count += 1
            
            # Need to run garabge collector manually, it seems to fill up memory very quickly
            if count % 20 == 0:
                gc.collect()
# Out:
# wrong: drinking/17.mp4 => writing_on_a_board
# in top 5: drinking/32.mp4 => ['washing_dishes', 'blowing_bubbles', 'waving_hands', 'drinking', 'applauding']
# wrong: drinking/30.mp4 => watching_TV
# correct: drinking/38.mp4 => drinking
# in top 5: drinking/57.mp4 => ['watching_TV', 'drinking', 'pouring_liquid', 'brushing_teeth', 'writing_on_a_board']
# in top 5: drinking/46.mp4 => ['drinking', 'blowing_bubbles', 'brushing_teeth', 'reading', 'writing_on_a_book']
# in top 5: drinking/63.mp4 => ['waving_hands', 'pushing_a_cart', 'blowing_bubbles', 'drinking', 'brushing_teeth']
# wrong: drinking/8.mp4 => taking_photos
# in top 5: drinking/5.mp4 => ['writing_on_a_board', 'playing_guitar', 'running', 'drinking', 'applauding']
# in top 5: drinking/69.mp4 => ['pouring_liquid', 'drinking', 'waving_hands', 'writing_on_a_book', 'brushing_teeth']
# correct: drinking/77.mp4 => drinking
# in top 5: drinking/54.mp4 => ['texting_message', 'brushing_teeth', 'drinking', 'pouring_liquid', 'applauding']
# correct: drinking/2.mp4 => drinking
# correct: drinking/12.mp4 => drinking
# correct: drinking/39.mp4 => drinking
# wrong: drinking/42.mp4 => cutting_trees
# in top 5: drinking/16.mp4 => ['writing_on_a_book', 'drinking', 'reading', 'applauding', 'pouring_liquid']
# correct: drinking/79.mp4 => drinking
# wrong: drinking/58.mp4 => looking_through_a_microscope
# wrong: drinking/80.mp4 => pouring_liquid
# correct: drinking/55.mp4 => drinking
# wrong: drinking/85.mp4 => throwing_frisby
# correct: drinking/73.mp4 => drinking
# wrong: drinking/87.mp4 => taking_photos
# wrong: drinking/3.mp4 => applauding
# wrong: drinking/14.mp4 => writing_on_a_board
# correct: drinking/76.mp4 => drinking
# in top 5: drinking/41.mp4 => ['reading', 'fixing_a_car', 'drinking', 'looking_through_a_microscope', 'pouring_liquid']
# in top 5: drinking/43.mp4 => ['drinking', 'blowing_bubbles', 'brushing_teeth', 'writing_on_a_book', 'applauding']
# in top 5: drinking/50.mp4 => ['applauding', 'blowing_bubbles', 'waving_hands', 'drinking', 'brushing_teeth']
# correct: drinking/60.mp4 => drinking
# correct: drinking/89.mp4 => drinking
# correct: drinking/15.mp4 => drinking
# wrong: drinking/48.mp4 => applauding
# in top 5: drinking/61.mp4 => ['blowing_bubbles', 'waving_hands', 'drinking', 'applauding', 'writing_on_a_board']
# correct: drinking/11.mp4 => drinking
# wrong: drinking/68.mp4 => watching_TV
# in top 5: drinking/20.mp4 => ['smoking', 'brushing_teeth', 'looking_through_a_microscope', 'drinking', 'phoning']
# correct: drinking/59.mp4 => drinking
# wrong: drinking/7.mp4 => writing_on_a_board
# in top 5: drinking/81.mp4 => ['running', 'drinking', 'writing_on_a_board', 'taking_photos', 'looking_through_a_telescope']
# wrong: drinking/88.mp4 => applauding
# correct: drinking/45.mp4 => drinking
# wrong: drinking/1.mp4 => pushing_a_cart
# wrong: drinking/35.mp4 => writing_on_a_board
# correct: drinking/31.mp4 => drinking
# in top 5: drinking/82.mp4 => ['smoking', 'drinking', 'texting_message', 'writing_on_a_board', 'applauding']
# in top 5: drinking/53.mp4 => ['using_a_computer', 'writing_on_a_board', 'drinking', 'pouring_liquid', 'reading']
# correct: drinking/9.mp4 => drinking
# in top 5: drinking/34.mp4 => ['drinking', 'taking_photos', 'writing_on_a_board', 'applauding', 'pushing_a_cart']
# correct: drinking/84.mp4 => drinking
# correct: drinking/51.mp4 => drinking
# correct: drinking/28.mp4 => drinking
# in top 5: drinking/56.mp4 => ['writing_on_a_board', 'blowing_bubbles', 'applauding', 'drinking', 'brushing_teeth']
# wrong: drinking/19.mp4 => running
# correct: drinking/75.mp4 => drinking
# wrong: drinking/27.mp4 => waving_hands
# in top 5: drinking/52.mp4 => ['taking_photos', 'writing_on_a_board', 'watching_TV', 'drinking', 'applauding']
# correct: drinking/74.mp4 => drinking
# in top 5: drinking/33.mp4 => ['drinking', 'pouring_liquid', 'looking_through_a_telescope', 'watching_TV', 'writing_on_a_board']
# correct: drinking/13.mp4 => drinking
# correct: drinking/6.mp4 => drinking
# wrong: drinking/70.mp4 => pouring_liquid
# wrong: drinking/67.mp4 => washing_dishes
# in top 5: drinking/72.mp4 => ['brushing_teeth', 'drinking', 'watching_TV', 'looking_through_a_telescope', 'writing_on_a_board']
# wrong: drinking/49.mp4 => writing_on_a_book
# correct: drinking/62.mp4 => drinking
# wrong: drinking/40.mp4 => reading
# wrong: drinking/18.mp4 => waving_hands
# wrong: drinking/37.mp4 => looking_through_a_microscope
# in top 5: drinking/47.mp4 => ['brushing_teeth', 'cutting_vegetables', 'pouring_liquid', 'drinking', 'washing_dishes']
# correct: drinking/86.mp4 => drinking
# in top 5: drinking/4.mp4 => ['pouring_liquid', 'applauding', 'drinking', 'running', 'taking_photos']
# in top 5: drinking/66.mp4 => ['writing_on_a_book', 'pouring_liquid', 'reading', 'drinking', 'applauding']
# wrong: drinking/71.mp4 => looking_through_a_telescope
# in top 5: drinking/36.mp4 => ['writing_on_a_book', 'smoking', 'drinking', 'texting_message', 'pouring_liquid']
# correct: texting/17.mp4 => texting_message
# wrong: texting/32.mp4 => writing_on_a_board
# in top 5: texting/30.mp4 => ['applauding', 'reading', 'writing_on_a_book', 'texting_message', 'waving_hands']
# wrong: texting/29.mp4 => running
# in top 5: texting/57.mp4 => ['phoning', 'applauding', 'watching_TV', 'texting_message', 'writing_on_a_board']
# correct: texting/46.mp4 => texting_message
# correct: texting/8.mp4 => texting_message
# wrong: texting/5.mp4 => writing_on_a_board
# in top 5: texting/69.mp4 => ['texting_message', 'writing_on_a_book', 'applauding', 'writing_on_a_board', 'using_a_computer']
# correct: texting/77.mp4 => texting_message
# wrong: texting/54.mp4 => waving_hands
# in top 5: texting/65.mp4 => ['taking_photos', 'texting_message', 'writing_on_a_board', 'running', 'waving_hands']
# wrong: texting/2.mp4 => cleaning_the_floor
# wrong: texting/12.mp4 => running
# in top 5: texting/39.mp4 => ['pushing_a_cart', 'phoning', 'looking_through_a_microscope', 'texting_message', 'fixing_a_car']
# in top 5: texting/42.mp4 => ['reading', 'waving_hands', 'writing_on_a_board', 'texting_message', 'watching_TV']
# correct: texting/16.mp4 => texting_message
# in top 5: texting/79.mp4 => ['using_a_computer', 'drinking', 'writing_on_a_board', 'texting_message', 'watching_TV']
# correct: texting/58.mp4 => texting_message
# wrong: texting/80.mp4 => running
# correct: texting/55.mp4 => texting_message
# correct: texting/85.mp4 => texting_message
# wrong: texting/73.mp4 => writing_on_a_board
# correct: texting/78.mp4 => texting_message
# wrong: texting/87.mp4 => watching_TV
# in top 5: texting/3.mp4 => ['pushing_a_cart', 'phoning', 'running', 'texting_message', 'taking_photos']
# in top 5: texting/14.mp4 => ['taking_photos', 'phoning', 'watching_TV', 'texting_message', 'writing_on_a_board']
# in top 5: texting/76.mp4 => ['texting_message', 'looking_through_a_telescope', 'fixing_a_car', 'waving_hands', 'writing_on_a_book']
# correct: texting/41.mp4 => texting_message
# wrong: texting/43.mp4 => taking_photos
# wrong: texting/50.mp4 => writing_on_a_board
# in top 5: texting/60.mp4 => ['reading', 'texting_message', 'taking_photos', 'phoning', 'writing_on_a_book']
# correct: texting/89.mp4 => texting_message
# in top 5: texting/64.mp4 => ['using_a_computer', 'reading', 'texting_message', 'brushing_teeth', 'writing_on_a_board']
# correct: texting/48.mp4 => texting_message
# in top 5: texting/61.mp4 => ['running', 'reading', 'taking_photos', 'texting_message', 'phoning']
# correct: texting/11.mp4 => texting_message
# correct: texting/68.mp4 => texting_message
# correct: texting/20.mp4 => texting_message
# wrong: texting/59.mp4 => taking_photos
# in top 5: texting/7.mp4 => ['drinking', 'writing_on_a_book', 'reading', 'texting_message', 'pouring_liquid']
# wrong: texting/44.mp4 => cutting_vegetables
# in top 5: texting/81.mp4 => ['smoking', 'writing_on_a_board', 'texting_message', 'fixing_a_car', 'waving_hands']
# correct: texting/88.mp4 => texting_message
# correct: texting/45.mp4 => texting_message
# correct: texting/1.mp4 => texting_message
# correct: texting/35.mp4 => texting_message
# wrong: texting/31.mp4 => applauding
# in top 5: texting/82.mp4 => ['writing_on_a_board', 'looking_through_a_microscope', 'texting_message', 'applauding', 'reading']
# in top 5: texting/53.mp4 => ['writing_on_a_book', 'taking_photos', 'applauding', 'texting_message', 'phoning']
# in top 5: texting/9.mp4 => ['reading', 'looking_through_a_microscope', 'texting_message', 'watching_TV', 'writing_on_a_board']
# correct: texting/34.mp4 => texting_message
# correct: texting/28.mp4 => texting_message
# in top 5: texting/56.mp4 => ['applauding', 'brushing_teeth', 'waving_hands', 'texting_message', 'smoking']
# wrong: texting/90.mp4 => writing_on_a_board
# in top 5: texting/19.mp4 => ['looking_through_a_telescope', 'taking_photos', 'phoning', 'texting_message', 'writing_on_a_board']
# correct: texting/75.mp4 => texting_message
# correct: texting/21.mp4 => texting_message
# wrong: texting/10.mp4 => using_a_computer
# correct: texting/52.mp4 => texting_message
# correct: texting/74.mp4 => texting_message
# in top 5: texting/33.mp4 => ['reading', 'smoking', 'waving_hands', 'texting_message', 'watching_TV']
# correct: texting/13.mp4 => texting_message
# correct: texting/91.mp4 => texting_message
# in top 5: texting/6.mp4 => ['smoking', 'watching_TV', 'taking_photos', 'texting_message', 'phoning']
# wrong: texting/70.mp4 => waving_hands
# wrong: texting/72.mp4 => writing_on_a_board
# correct: texting/49.mp4 => texting_message
# in top 5: texting/62.mp4 => ['watching_TV', 'using_a_computer', 'taking_photos', 'texting_message', 'phoning']
# in top 5: texting/40.mp4 => ['writing_on_a_book', 'smoking', 'phoning', 'texting_message', 'brushing_teeth']
# correct: texting/18.mp4 => texting_message
# correct: texting/37.mp4 => texting_message
# in top 5: texting/47.mp4 => ['writing_on_a_book', 'fixing_a_car', 'looking_through_a_telescope', 'texting_message', 'waving_hands']
# correct: texting/86.mp4 => texting_message
# wrong: texting/4.mp4 => waving_hands
# correct: texting/66.mp4 => texting_message
# correct: texting/71.mp4 => texting_message
# in top 5: texting/36.mp4 => ['phoning', 'waving_hands', 'writing_on_a_book', 'texting_message', 'running']
# correct: playing_violin/32.mp4 => playing_violin
# in top 5: playing_violin/30.mp4 => ['taking_photos', 'shooting_an_arrow', 'playing_violin', 'cleaning_the_floor', 'applauding']
# wrong: playing_violin/29.mp4 => writing_on_a_board
# in top 5: playing_violin/38.mp4 => ['drinking', 'looking_through_a_telescope', 'applauding', 'playing_violin', 'playing_guitar']
# correct: playing_violin/57.mp4 => playing_violin
# correct: playing_violin/46.mp4 => playing_violin
# correct: playing_violin/63.mp4 => playing_violin
# correct: playing_violin/5.mp4 => playing_violin
# correct: playing_violin/69.mp4 => playing_violin
# correct: playing_violin/77.mp4 => playing_violin
# correct: playing_violin/54.mp4 => playing_violin
# correct: playing_violin/65.mp4 => playing_violin
# in top 5: playing_violin/2.mp4 => ['playing_violin', 'taking_photos', 'applauding', 'playing_guitar', 'blowing_bubbles']
# correct: playing_violin/12.mp4 => playing_violin
# correct: playing_violin/42.mp4 => playing_violin
# in top 5: playing_violin/79.mp4 => ['writing_on_a_board', 'looking_through_a_telescope', 'playing_violin', 'applauding', 'playing_guitar']
# correct: playing_violin/58.mp4 => playing_violin
# correct: playing_violin/80.mp4 => playing_violin
# correct: playing_violin/55.mp4 => playing_violin
# wrong: playing_violin/85.mp4 => applauding
# correct: playing_violin/73.mp4 => playing_violin
# correct: playing_violin/78.mp4 => playing_violin
# correct: playing_violin/3.mp4 => playing_violin
# in top 5: playing_violin/14.mp4 => ['drinking', 'applauding', 'playing_violin', 'pouring_liquid', 'writing_on_a_book']
# correct: playing_violin/76.mp4 => playing_violin
# correct: playing_violin/41.mp4 => playing_violin
# correct: playing_violin/50.mp4 => playing_violin
# correct: playing_violin/92.mp4 => playing_violin
# correct: playing_violin/60.mp4 => playing_violin
# correct: playing_violin/15.mp4 => playing_violin
# correct: playing_violin/64.mp4 => playing_violin
# correct: playing_violin/48.mp4 => playing_violin
# correct: playing_violin/61.mp4 => playing_violin
# correct: playing_violin/11.mp4 => playing_violin
# correct: playing_violin/83.mp4 => playing_violin
# correct: playing_violin/68.mp4 => playing_violin
# correct: playing_violin/59.mp4 => playing_violin
# correct: playing_violin/7.mp4 => playing_violin
# correct: playing_violin/81.mp4 => playing_violin
# correct: playing_violin/88.mp4 => playing_violin
# correct: playing_violin/1.mp4 => playing_violin
# correct: playing_violin/35.mp4 => playing_violin
# correct: playing_violin/31.mp4 => playing_violin
# correct: playing_violin/24.mp4 => playing_violin
# correct: playing_violin/82.mp4 => playing_violin
# correct: playing_violin/53.mp4 => playing_violin
# correct: playing_violin/9.mp4 => playing_violin
# in top 5: playing_violin/34.mp4 => ['playing_guitar', 'waving_hands', 'playing_violin', 'taking_photos', 'writing_on_a_board']
# correct: playing_violin/26.mp4 => playing_violin
# correct: playing_violin/51.mp4 => playing_violin
# correct: playing_violin/28.mp4 => playing_violin
# correct: playing_violin/56.mp4 => playing_violin
# correct: playing_violin/22.mp4 => playing_violin
# correct: playing_violin/90.mp4 => playing_violin
# correct: playing_violin/25.mp4 => playing_violin
# in top 5: playing_violin/75.mp4 => ['reading', 'writing_on_a_book', 'playing_violin', 'playing_guitar', 'applauding']
# correct: playing_violin/27.mp4 => playing_violin
# in top 5: playing_violin/21.mp4 => ['applauding', 'waving_hands', 'fishing', 'playing_violin', 'playing_guitar']
# correct: playing_violin/10.mp4 => playing_violin
# correct: playing_violin/52.mp4 => playing_violin
# correct: playing_violin/74.mp4 => playing_violin
# correct: playing_violin/33.mp4 => playing_violin
# wrong: playing_violin/23.mp4 => taking_photos
# correct: playing_violin/13.mp4 => playing_violin
# correct: playing_violin/91.mp4 => playing_violin
# correct: playing_violin/6.mp4 => playing_violin
# wrong: playing_violin/70.mp4 => writing_on_a_board
# correct: playing_violin/67.mp4 => playing_violin
# correct: playing_violin/72.mp4 => playing_violin
# correct: playing_violin/49.mp4 => playing_violin
# correct: playing_violin/62.mp4 => playing_violin
# correct: playing_violin/40.mp4 => playing_violin
# in top 5: playing_violin/93.mp4 => ['playing_violin', 'writing_on_a_board', 'applauding', 'playing_guitar', 'taking_photos']
# in top 5: playing_violin/37.mp4 => ['taking_photos', 'blowing_bubbles', 'writing_on_a_board', 'playing_violin', 'applauding']
# correct: playing_violin/47.mp4 => playing_violin
# correct: playing_violin/4.mp4 => playing_violin
# correct: playing_violin/66.mp4 => playing_violin
# in top 5: playing_violin/71.mp4 => ['looking_through_a_microscope', 'looking_through_a_telescope', 'watching_TV', 'playing_violin', 'writing_on_a_board']
# correct: playing_violin/36.mp4 => playing_violin
# wrong: washing_dishes/17.mp4 => taking_photos
# correct: washing_dishes/29.mp4 => washing_dishes
# in top 5: washing_dishes/38.mp4 => ['cleaning_the_floor', 'washing_dishes', 'cutting_vegetables', 'writing_on_a_board', 'watching_TV']
# correct: washing_dishes/57.mp4 => washing_dishes
# in top 5: washing_dishes/46.mp4 => ['writing_on_a_book', 'blowing_bubbles', 'pouring_liquid', 'washing_dishes', 'looking_through_a_microscope']
# correct: washing_dishes/63.mp4 => washing_dishes
# correct: washing_dishes/8.mp4 => washing_dishes
# correct: washing_dishes/5.mp4 => washing_dishes
# in top 5: washing_dishes/69.mp4 => ['pouring_liquid', 'watching_TV', 'washing_dishes', 'looking_through_a_microscope', 'writing_on_a_book']
# in top 5: washing_dishes/77.mp4 => ['drinking', 'washing_dishes', 'pouring_liquid', 'applauding', 'looking_through_a_microscope']
# wrong: washing_dishes/54.mp4 => texting_message
# in top 5: washing_dishes/65.mp4 => ['pouring_liquid', 'brushing_teeth', 'washing_dishes', 'looking_through_a_microscope', 'writing_on_a_board']
# wrong: washing_dishes/2.mp4 => looking_through_a_microscope
# in top 5: washing_dishes/12.mp4 => ['looking_through_a_microscope', 'blowing_bubbles', 'cooking', 'washing_dishes', 'pouring_liquid']
# correct: washing_dishes/39.mp4 => washing_dishes
# correct: washing_dishes/42.mp4 => washing_dishes
# correct: washing_dishes/16.mp4 => washing_dishes
# correct: washing_dishes/79.mp4 => washing_dishes
# correct: washing_dishes/58.mp4 => washing_dishes
# in top 5: washing_dishes/80.mp4 => ['using_a_computer', 'looking_through_a_microscope', 'writing_on_a_board', 'washing_dishes', 'cleaning_the_floor']
# correct: washing_dishes/55.mp4 => washing_dishes
# correct: washing_dishes/85.mp4 => washing_dishes
# in top 5: washing_dishes/73.mp4 => ['looking_through_a_microscope', 'cutting_vegetables', 'washing_dishes', 'cooking', 'pouring_liquid']
# correct: washing_dishes/78.mp4 => washing_dishes
# in top 5: washing_dishes/87.mp4 => ['washing_dishes', 'reading', 'cutting_vegetables', 'writing_on_a_book', 'looking_through_a_microscope']
# in top 5: washing_dishes/3.mp4 => ['drinking', 'pouring_liquid', 'cooking', 'washing_dishes', 'cutting_vegetables']
# in top 5: washing_dishes/14.mp4 => ['pouring_liquid', 'writing_on_a_book', 'washing_dishes', 'cutting_vegetables', 'cooking']
# in top 5: washing_dishes/76.mp4 => ['pouring_liquid', 'looking_through_a_microscope', 'cutting_vegetables', 'washing_dishes', 'cooking']
# correct: washing_dishes/41.mp4 => washing_dishes
# correct: washing_dishes/43.mp4 => washing_dishes
# wrong: washing_dishes/50.mp4 => looking_through_a_telescope
# correct: washing_dishes/60.mp4 => washing_dishes
# correct: washing_dishes/89.mp4 => washing_dishes
# correct: washing_dishes/15.mp4 => washing_dishes
# correct: washing_dishes/64.mp4 => washing_dishes
# correct: washing_dishes/48.mp4 => washing_dishes
# correct: washing_dishes/61.mp4 => washing_dishes
# correct: washing_dishes/11.mp4 => washing_dishes
# in top 5: washing_dishes/83.mp4 => ['washing_dishes', 'writing_on_a_book', 'brushing_teeth', 'applauding', 'looking_through_a_microscope']
# in top 5: washing_dishes/68.mp4 => ['washing_dishes', 'pouring_liquid', 'cutting_vegetables', 'cooking', 'looking_through_a_microscope']
# correct: washing_dishes/20.mp4 => washing_dishes
# correct: washing_dishes/59.mp4 => washing_dishes
# in top 5: washing_dishes/7.mp4 => ['cooking', 'writing_on_a_board', 'washing_dishes', 'watching_TV', 'looking_through_a_microscope']
# correct: washing_dishes/44.mp4 => washing_dishes
# correct: washing_dishes/81.mp4 => washing_dishes
# correct: washing_dishes/88.mp4 => washing_dishes
# correct: washing_dishes/45.mp4 => washing_dishes
# correct: washing_dishes/1.mp4 => washing_dishes
# in top 5: washing_dishes/35.mp4 => ['pouring_liquid', 'writing_on_a_book', 'cooking', 'washing_dishes', 'cutting_vegetables']
# correct: washing_dishes/24.mp4 => washing_dishes
# in top 5: washing_dishes/82.mp4 => ['writing_on_a_book', 'watching_TV', 'pouring_liquid', 'washing_dishes', 'cutting_vegetables']
# correct: washing_dishes/53.mp4 => washing_dishes
# correct: washing_dishes/9.mp4 => washing_dishes
# in top 5: washing_dishes/34.mp4 => ['cutting_vegetables', 'cooking', 'pouring_liquid', 'washing_dishes', 'drinking']
# correct: washing_dishes/26.mp4 => washing_dishes
# wrong: washing_dishes/84.mp4 => applauding
# in top 5: washing_dishes/51.mp4 => ['cutting_vegetables', 'applauding', 'washing_dishes', 'pouring_liquid', 'cooking']
# correct: washing_dishes/28.mp4 => washing_dishes
# wrong: washing_dishes/56.mp4 => cutting_trees
# correct: washing_dishes/22.mp4 => washing_dishes
# correct: washing_dishes/90.mp4 => washing_dishes
# correct: washing_dishes/19.mp4 => washing_dishes
# correct: washing_dishes/25.mp4 => washing_dishes
# correct: washing_dishes/75.mp4 => washing_dishes
# correct: washing_dishes/27.mp4 => washing_dishes
# in top 5: washing_dishes/21.mp4 => ['cooking', 'looking_through_a_microscope', 'cutting_vegetables', 'washing_dishes', 'cleaning_the_floor']
# wrong: washing_dishes/10.mp4 => pushing_a_cart
# in top 5: washing_dishes/52.mp4 => ['watching_TV', 'cooking', 'washing_dishes', 'looking_through_a_microscope', 'writing_on_a_board']
# correct: washing_dishes/74.mp4 => washing_dishes
# in top 5: washing_dishes/33.mp4 => ['running', 'cooking', 'washing_dishes', 'cutting_vegetables', 'cleaning_the_floor']
# in top 5: washing_dishes/23.mp4 => ['pouring_liquid', 'brushing_teeth', 'washing_dishes', 'looking_through_a_microscope', 'writing_on_a_board']
# correct: washing_dishes/13.mp4 => washing_dishes
# correct: washing_dishes/6.mp4 => washing_dishes
# correct: washing_dishes/70.mp4 => washing_dishes
# correct: washing_dishes/67.mp4 => washing_dishes
# wrong: washing_dishes/72.mp4 => looking_through_a_microscope
# correct: washing_dishes/49.mp4 => washing_dishes
# wrong: washing_dishes/62.mp4 => drinking
# correct: washing_dishes/40.mp4 => washing_dishes
# correct: washing_dishes/18.mp4 => washing_dishes
# correct: washing_dishes/37.mp4 => washing_dishes
# correct: washing_dishes/47.mp4 => washing_dishes
# wrong: washing_dishes/86.mp4 => cleaning_the_floor
# wrong: washing_dishes/4.mp4 => watching_TV
# wrong: washing_dishes/66.mp4 => cleaning_the_floor
# correct: washing_dishes/71.mp4 => washing_dishes
# correct: washing_dishes/36.mp4 => washing_dishes
# wrong: walking_the_dog/17.mp4 => jumping
# correct: walking_the_dog/32.mp4 => walking_the_dog
# correct: walking_the_dog/30.mp4 => walking_the_dog
# correct: walking_the_dog/29.mp4 => walking_the_dog
# in top 5: walking_the_dog/38.mp4 => ['cutting_trees', 'looking_through_a_telescope', 'blowing_bubbles', 'walking_the_dog', 'fishing']
# wrong: walking_the_dog/57.mp4 => running
# correct: walking_the_dog/46.mp4 => walking_the_dog
# in top 5: walking_the_dog/63.mp4 => ['riding_a_bike', 'fishing', 'pushing_a_cart', 'walking_the_dog', 'running']
# in top 5: walking_the_dog/8.mp4 => ['jumping', 'looking_through_a_telescope', 'walking_the_dog', 'running', 'fishing']
# correct: walking_the_dog/5.mp4 => walking_the_dog
# in top 5: walking_the_dog/69.mp4 => ['cleaning_the_floor', 'walking_the_dog', 'running', 'watching_TV', 'writing_on_a_board']
# correct: walking_the_dog/77.mp4 => walking_the_dog
# correct: walking_the_dog/54.mp4 => walking_the_dog
# in top 5: walking_the_dog/65.mp4 => ['taking_photos', 'throwing_frisby', 'cutting_trees', 'walking_the_dog', 'gardening']
# correct: walking_the_dog/2.mp4 => walking_the_dog
# wrong: walking_the_dog/12.mp4 => cleaning_the_floor
# correct: walking_the_dog/39.mp4 => walking_the_dog
# correct: walking_the_dog/42.mp4 => walking_the_dog
# correct: walking_the_dog/16.mp4 => walking_the_dog
# wrong: walking_the_dog/79.mp4 => climbing
# wrong: walking_the_dog/80.mp4 => looking_through_a_telescope
# in top 5: walking_the_dog/55.mp4 => ['blowing_bubbles', 'jumping', 'walking_the_dog', 'waving_hands', 'gardening']
# in top 5: walking_the_dog/85.mp4 => ['texting_message', 'walking_the_dog', 'writing_on_a_book', 'gardening', 'waving_hands']
# in top 5: walking_the_dog/73.mp4 => ['running', 'riding_a_horse', 'throwing_frisby', 'walking_the_dog', 'gardening']
# wrong: walking_the_dog/78.mp4 => running
# in top 5: walking_the_dog/87.mp4 => ['pushing_a_cart', 'riding_a_bike', 'feeding_a_horse', 'walking_the_dog', 'running']
# in top 5: walking_the_dog/3.mp4 => ['waving_hands', 'phoning', 'walking_the_dog', 'taking_photos', 'running']
# wrong: walking_the_dog/14.mp4 => fishing
# wrong: walking_the_dog/76.mp4 => running
# correct: walking_the_dog/41.mp4 => walking_the_dog
# correct: walking_the_dog/43.mp4 => walking_the_dog
# correct: walking_the_dog/50.mp4 => walking_the_dog
# in top 5: walking_the_dog/92.mp4 => ['throwing_frisby', 'taking_photos', 'applauding', 'walking_the_dog', 'running']
# wrong: walking_the_dog/60.mp4 => running
# in top 5: walking_the_dog/89.mp4 => ['gardening', 'jumping', 'running', 'walking_the_dog', 'throwing_frisby']
# in top 5: walking_the_dog/15.mp4 => ['blowing_bubbles', 'throwing_frisby', 'running', 'walking_the_dog', 'jumping']
# correct: walking_the_dog/64.mp4 => walking_the_dog
# in top 5: walking_the_dog/48.mp4 => ['cutting_vegetables', 'running', 'walking_the_dog', 'throwing_frisby', 'looking_through_a_telescope']
# wrong: walking_the_dog/61.mp4 => gardening
# in top 5: walking_the_dog/11.mp4 => ['jumping', 'taking_photos', 'walking_the_dog', 'writing_on_a_board', 'running']
# correct: walking_the_dog/83.mp4 => walking_the_dog
# correct: walking_the_dog/68.mp4 => walking_the_dog
# wrong: walking_the_dog/20.mp4 => cleaning_the_floor
# in top 5: walking_the_dog/59.mp4 => ['looking_through_a_telescope', 'shooting_an_arrow', 'walking_the_dog', 'throwing_frisby', 'running']
# correct: walking_the_dog/7.mp4 => walking_the_dog
# in top 5: walking_the_dog/44.mp4 => ['smoking', 'looking_through_a_telescope', 'walking_the_dog', 'waving_hands', 'gardening']
# correct: walking_the_dog/81.mp4 => walking_the_dog
# correct: walking_the_dog/88.mp4 => walking_the_dog
# correct: walking_the_dog/45.mp4 => walking_the_dog
# in top 5: walking_the_dog/1.mp4 => ['running', 'shooting_an_arrow', 'feeding_a_horse', 'walking_the_dog', 'cutting_trees']
# in top 5: walking_the_dog/35.mp4 => ['pushing_a_cart', 'walking_the_dog', 'riding_a_bike', 'fishing', 'running']
# wrong: walking_the_dog/31.mp4 => applauding
# wrong: walking_the_dog/9.mp4 => gardening
# correct: walking_the_dog/26.mp4 => walking_the_dog
# wrong: walking_the_dog/84.mp4 => running
# in top 5: walking_the_dog/51.mp4 => ['fishing', 'jumping', 'pushing_a_cart', 'walking_the_dog', 'running']
# in top 5: walking_the_dog/28.mp4 => ['riding_a_bike', 'using_a_computer', 'taking_photos', 'walking_the_dog', 'running']
# correct: walking_the_dog/56.mp4 => walking_the_dog
# wrong: walking_the_dog/90.mp4 => cleaning_the_floor
# correct: walking_the_dog/19.mp4 => walking_the_dog
# wrong: walking_the_dog/75.mp4 => taking_photos
# in top 5: walking_the_dog/27.mp4 => ['running', 'walking_the_dog', 'taking_photos', 'gardening', 'writing_on_a_board']
# correct: walking_the_dog/10.mp4 => walking_the_dog
# correct: walking_the_dog/52.mp4 => walking_the_dog
# correct: walking_the_dog/74.mp4 => walking_the_dog
# wrong: walking_the_dog/33.mp4 => writing_on_a_board
# in top 5: walking_the_dog/13.mp4 => ['looking_through_a_telescope', 'running', 'cutting_trees', 'walking_the_dog', 'writing_on_a_board']
# in top 5: walking_the_dog/91.mp4 => ['waving_hands', 'jumping', 'walking_the_dog', 'running', 'gardening']
# wrong: walking_the_dog/6.mp4 => running
# correct: walking_the_dog/70.mp4 => walking_the_dog
# wrong: walking_the_dog/67.mp4 => climbing
# in top 5: walking_the_dog/72.mp4 => ['applauding', 'walking_the_dog', 'riding_a_bike', 'waving_hands', 'running']
# correct: walking_the_dog/95.mp4 => walking_the_dog
# in top 5: walking_the_dog/49.mp4 => ['feeding_a_horse', 'cutting_trees', 'writing_on_a_board', 'walking_the_dog', 'watching_TV']
# correct: walking_the_dog/62.mp4 => walking_the_dog
# in top 5: walking_the_dog/40.mp4 => ['throwing_frisby', 'shooting_an_arrow', 'walking_the_dog', 'running', 'jumping']
# in top 5: walking_the_dog/93.mp4 => ['taking_photos', 'riding_a_bike', 'walking_the_dog', 'fishing', 'running']
# correct: walking_the_dog/18.mp4 => walking_the_dog
# correct: walking_the_dog/94.mp4 => walking_the_dog
# wrong: walking_the_dog/37.mp4 => cleaning_the_floor
# in top 5: walking_the_dog/47.mp4 => ['taking_photos', 'looking_through_a_telescope', 'walking_the_dog', 'fishing', 'running']
# wrong: walking_the_dog/86.mp4 => applauding
# correct: walking_the_dog/4.mp4 => walking_the_dog
# correct: walking_the_dog/66.mp4 => walking_the_dog
# correct: walking_the_dog/36.mp4 => walking_the_dog
# in top 5: reading_book/32.mp4 => ['watching_TV', 'looking_through_a_microscope', 'using_a_computer', 'reading', 'writing_on_a_book']
# in top 5: reading_book/30.mp4 => ['looking_through_a_microscope', 'cutting_vegetables', 'drinking', 'reading', 'writing_on_a_book']
# in top 5: reading_book/29.mp4 => ['writing_on_a_book', 'cutting_vegetables', 'applauding', 'reading', 'writing_on_a_board']
# in top 5: reading_book/38.mp4 => ['using_a_computer', 'looking_through_a_microscope', 'writing_on_a_board', 'reading', 'writing_on_a_book']
# correct: reading_book/57.mp4 => reading
# in top 5: reading_book/46.mp4 => ['pouring_liquid', 'using_a_computer', 'looking_through_a_microscope', 'reading', 'writing_on_a_book']
# correct: reading_book/8.mp4 => reading
# correct: reading_book/5.mp4 => reading
# correct: reading_book/69.mp4 => reading
# correct: reading_book/77.mp4 => reading
# in top 5: reading_book/54.mp4 => ['looking_through_a_microscope', 'brushing_teeth', 'reading', 'writing_on_a_book', 'writing_on_a_board']
# in top 5: reading_book/65.mp4 => ['pouring_liquid', 'looking_through_a_microscope', 'reading', 'writing_on_a_book', 'cutting_vegetables']
# correct: reading_book/2.mp4 => reading
# correct: reading_book/12.mp4 => reading
# in top 5: reading_book/39.mp4 => ['pouring_liquid', 'using_a_computer', 'cutting_vegetables', 'reading', 'writing_on_a_book']
# wrong: reading_book/42.mp4 => writing_on_a_book
# correct: reading_book/16.mp4 => reading
# wrong: reading_book/79.mp4 => writing_on_a_book
# correct: reading_book/58.mp4 => reading
# correct: reading_book/80.mp4 => reading
# correct: reading_book/55.mp4 => reading
# in top 5: reading_book/85.mp4 => ['waving_hands', 'drinking', 'writing_on_a_book', 'reading', 'writing_on_a_board']
# in top 5: reading_book/73.mp4 => ['using_a_computer', 'texting_message', 'reading', 'cutting_vegetables', 'writing_on_a_book']
# wrong: reading_book/78.mp4 => playing_guitar
# in top 5: reading_book/87.mp4 => ['cleaning_the_floor', 'using_a_computer', 'watching_TV', 'reading', 'writing_on_a_book']
# in top 5: reading_book/14.mp4 => ['cutting_vegetables', 'washing_dishes', 'using_a_computer', 'reading', 'writing_on_a_book']
# wrong: reading_book/76.mp4 => writing_on_a_book
# in top 5: reading_book/41.mp4 => ['pouring_liquid', 'writing_on_a_book', 'cutting_vegetables', 'reading', 'writing_on_a_board']
# correct: reading_book/43.mp4 => reading
# correct: reading_book/92.mp4 => reading
# in top 5: reading_book/60.mp4 => ['pouring_liquid', 'looking_through_a_microscope', 'reading', 'applauding', 'writing_on_a_book']
# correct: reading_book/89.mp4 => reading
# correct: reading_book/15.mp4 => reading
# correct: reading_book/64.mp4 => reading
# correct: reading_book/48.mp4 => reading
# in top 5: reading_book/61.mp4 => ['washing_dishes', 'cutting_vegetables', 'using_a_computer', 'reading', 'writing_on_a_book']
# correct: reading_book/11.mp4 => reading
# correct: reading_book/83.mp4 => reading
# correct: reading_book/68.mp4 => reading
# in top 5: reading_book/59.mp4 => ['watching_TV', 'drinking', 'writing_on_a_book', 'reading', 'looking_through_a_microscope']
# in top 5: reading_book/7.mp4 => ['pouring_liquid', 'cutting_vegetables', 'cleaning_the_floor', 'reading', 'writing_on_a_book']
# in top 5: reading_book/44.mp4 => ['phoning', 'drinking', 'reading', 'applauding', 'writing_on_a_board']
# in top 5: reading_book/81.mp4 => ['using_a_computer', 'cutting_vegetables', 'writing_on_a_board', 'reading', 'writing_on_a_book']
# in top 5: reading_book/88.mp4 => ['watching_TV', 'applauding', 'waving_hands', 'reading', 'writing_on_a_book']
# wrong: reading_book/45.mp4 => watching_TV
# wrong: reading_book/1.mp4 => writing_on_a_board
# wrong: reading_book/35.mp4 => taking_photos
# correct: reading_book/31.mp4 => reading
# in top 5: reading_book/24.mp4 => ['reading', 'waving_hands', 'applauding', 'holding_an_umbrella', 'writing_on_a_book']
# in top 5: reading_book/82.mp4 => ['applauding', 'pouring_liquid', 'reading', 'cutting_vegetables', 'writing_on_a_book']
# correct: reading_book/53.mp4 => reading
# in top 5: reading_book/9.mp4 => ['watching_TV', 'cleaning_the_floor', 'reading', 'writing_on_a_board', 'writing_on_a_book']
# in top 5: reading_book/34.mp4 => ['watching_TV', 'writing_on_a_board', 'looking_through_a_microscope', 'reading', 'writing_on_a_book']
# in top 5: reading_book/26.mp4 => ['drinking', 'writing_on_a_book', 'waving_hands', 'reading', 'writing_on_a_board']
# in top 5: reading_book/84.mp4 => ['cutting_vegetables', 'applauding', 'using_a_computer', 'reading', 'writing_on_a_book']
# correct: reading_book/51.mp4 => reading
# in top 5: reading_book/28.mp4 => ['using_a_computer', 'pouring_liquid', 'reading', 'looking_through_a_microscope', 'writing_on_a_book']
# in top 5: reading_book/56.mp4 => ['pouring_liquid', 'reading', 'fixing_a_bike', 'cutting_vegetables', 'writing_on_a_book']
# in top 5: reading_book/22.mp4 => ['pushing_a_cart', 'waving_hands', 'writing_on_a_book', 'reading', 'cleaning_the_floor']
# in top 5: reading_book/90.mp4 => ['using_a_computer', 'fixing_a_bike', 'reading', 'looking_through_a_microscope', 'writing_on_a_book']
# correct: reading_book/25.mp4 => reading
# in top 5: reading_book/75.mp4 => ['drinking', 'pouring_liquid', 'cutting_vegetables', 'reading', 'writing_on_a_book']
# in top 5: reading_book/27.mp4 => ['writing_on_a_board', 'watching_TV', 'reading', 'writing_on_a_book', 'using_a_computer']
# correct: reading_book/10.mp4 => reading
# correct: reading_book/52.mp4 => reading
# in top 5: reading_book/33.mp4 => ['using_a_computer', 'phoning', 'applauding', 'reading', 'writing_on_a_book']
# correct: reading_book/23.mp4 => reading
# correct: reading_book/13.mp4 => reading
# correct: reading_book/91.mp4 => reading
# correct: reading_book/6.mp4 => reading
# in top 5: reading_book/70.mp4 => ['writing_on_a_board', 'using_a_computer', 'waving_hands', 'reading', 'writing_on_a_book']
# in top 5: reading_book/67.mp4 => ['texting_message', 'drinking', 'writing_on_a_book', 'reading', 'writing_on_a_board']
# in top 5: reading_book/72.mp4 => ['phoning', 'reading', 'applauding', 'writing_on_a_book', 'waving_hands']
# correct: reading_book/49.mp4 => reading
# correct: reading_book/62.mp4 => reading
# wrong: reading_book/40.mp4 => looking_through_a_microscope
# in top 5: reading_book/37.mp4 => ['texting_message', 'using_a_computer', 'watching_TV', 'reading', 'writing_on_a_book']
# correct: reading_book/47.mp4 => reading
# in top 5: reading_book/86.mp4 => ['using_a_computer', 'watching_TV', 'washing_dishes', 'reading', 'writing_on_a_book']
# correct: reading_book/4.mp4 => reading
# in top 5: reading_book/66.mp4 => ['texting_message', 'applauding', 'using_a_computer', 'reading', 'writing_on_a_book']
# in top 5: reading_book/71.mp4 => ['climbing', 'reading', 'washing_dishes', 'jumping', 'brushing_teeth']
# correct: reading_book/36.mp4 => reading
# wrong: riding_or_walking_with_horse/17.mp4 => shooting_an_arrow
# correct: riding_or_walking_with_horse/32.mp4 => riding_a_horse
# in top 5: riding_or_walking_with_horse/30.mp4 => ['taking_photos', 'looking_through_a_telescope', 'smoking', 'riding_a_horse', 'feeding_a_horse']
# correct: riding_or_walking_with_horse/29.mp4 => riding_a_horse
# correct: riding_or_walking_with_horse/38.mp4 => riding_a_horse
# correct: riding_or_walking_with_horse/57.mp4 => riding_a_horse
# wrong: riding_or_walking_with_horse/46.mp4 => feeding_a_horse
# correct: riding_or_walking_with_horse/63.mp4 => riding_a_horse
# correct: riding_or_walking_with_horse/8.mp4 => riding_a_horse
# correct: riding_or_walking_with_horse/5.mp4 => riding_a_horse
# correct: riding_or_walking_with_horse/69.mp4 => riding_a_horse
# in top 5: riding_or_walking_with_horse/77.mp4 => ['running', 'gardening', 'waving_hands', 'riding_a_horse', 'feeding_a_horse']
# in top 5: riding_or_walking_with_horse/54.mp4 => ['throwing_frisby', 'jumping', 'riding_a_horse', 'running', 'feeding_a_horse']
# in top 5: riding_or_walking_with_horse/65.mp4 => ['throwing_frisby', 'shooting_an_arrow', 'running', 'riding_a_horse', 'feeding_a_horse']
# correct: riding_or_walking_with_horse/2.mp4 => riding_a_horse
# correct: riding_or_walking_with_horse/12.mp4 => riding_a_horse
# correct: riding_or_walking_with_horse/39.mp4 => riding_a_horse
# correct: riding_or_walking_with_horse/42.mp4 => riding_a_horse
# correct: riding_or_walking_with_horse/16.mp4 => riding_a_horse
# correct: riding_or_walking_with_horse/79.mp4 => riding_a_horse
# wrong: riding_or_walking_with_horse/58.mp4 => waving_hands
# correct: riding_or_walking_with_horse/80.mp4 => riding_a_horse
# correct: riding_or_walking_with_horse/55.mp4 => riding_a_horse
# in top 5: riding_or_walking_with_horse/85.mp4 => ['taking_photos', 'playing_guitar', 'riding_a_horse', 'cutting_trees', 'feeding_a_horse']
# correct: riding_or_walking_with_horse/73.mp4 => riding_a_horse
# correct: riding_or_walking_with_horse/78.mp4 => riding_a_horse
# correct: riding_or_walking_with_horse/87.mp4 => riding_a_horse
# correct: riding_or_walking_with_horse/3.mp4 => riding_a_horse
# correct: riding_or_walking_with_horse/14.mp4 => riding_a_horse
# correct: riding_or_walking_with_horse/76.mp4 => riding_a_horse
# correct: riding_or_walking_with_horse/41.mp4 => riding_a_horse
# correct: riding_or_walking_with_horse/43.mp4 => riding_a_horse
# correct: riding_or_walking_with_horse/50.mp4 => riding_a_horse
# correct: riding_or_walking_with_horse/15.mp4 => riding_a_horse
# correct: riding_or_walking_with_horse/64.mp4 => riding_a_horse
# correct: riding_or_walking_with_horse/48.mp4 => riding_a_horse
# correct: riding_or_walking_with_horse/11.mp4 => riding_a_horse
# correct: riding_or_walking_with_horse/83.mp4 => riding_a_horse
# correct: riding_or_walking_with_horse/68.mp4 => riding_a_horse
# correct: riding_or_walking_with_horse/20.mp4 => riding_a_horse
# correct: riding_or_walking_with_horse/59.mp4 => riding_a_horse
# correct: riding_or_walking_with_horse/7.mp4 => riding_a_horse
# correct: riding_or_walking_with_horse/81.mp4 => riding_a_horse
# correct: riding_or_walking_with_horse/88.mp4 => riding_a_horse
# in top 5: riding_or_walking_with_horse/45.mp4 => ['shooting_an_arrow', 'walking_the_dog', 'riding_a_horse', 'throwing_frisby', 'writing_on_a_board']
# in top 5: riding_or_walking_with_horse/1.mp4 => ['taking_photos', 'waving_hands', 'applauding', 'riding_a_horse', 'feeding_a_horse']
# correct: riding_or_walking_with_horse/35.mp4 => riding_a_horse
# in top 5: riding_or_walking_with_horse/31.mp4 => ['feeding_a_horse', 'throwing_frisby', 'riding_a_horse', 'walking_the_dog', 'running']
# correct: riding_or_walking_with_horse/53.mp4 => riding_a_horse
# correct: riding_or_walking_with_horse/9.mp4 => riding_a_horse
# correct: riding_or_walking_with_horse/34.mp4 => riding_a_horse
# wrong: riding_or_walking_with_horse/84.mp4 => running
# correct: riding_or_walking_with_horse/51.mp4 => riding_a_horse
# correct: riding_or_walking_with_horse/28.mp4 => riding_a_horse
# in top 5: riding_or_walking_with_horse/56.mp4 => ['applauding', 'running', 'writing_on_a_board', 'riding_a_horse', 'feeding_a_horse']
# wrong: riding_or_walking_with_horse/22.mp4 => writing_on_a_board
# in top 5: riding_or_walking_with_horse/19.mp4 => ['throwing_frisby', 'taking_photos', 'walking_the_dog', 'riding_a_horse', 'feeding_a_horse']
# in top 5: riding_or_walking_with_horse/27.mp4 => ['pushing_a_cart', 'running', 'looking_through_a_telescope', 'riding_a_horse', 'feeding_a_horse']
# correct: riding_or_walking_with_horse/21.mp4 => riding_a_horse
# in top 5: riding_or_walking_with_horse/10.mp4 => ['looking_through_a_telescope', 'throwing_frisby', 'running', 'riding_a_horse', 'feeding_a_horse']
# correct: riding_or_walking_with_horse/52.mp4 => riding_a_horse
# correct: riding_or_walking_with_horse/74.mp4 => riding_a_horse
# in top 5: riding_or_walking_with_horse/33.mp4 => ['applauding', 'riding_a_horse', 'feeding_a_horse', 'writing_on_a_board', 'watching_TV']
# correct: riding_or_walking_with_horse/23.mp4 => riding_a_horse
# correct: riding_or_walking_with_horse/13.mp4 => riding_a_horse
# correct: riding_or_walking_with_horse/6.mp4 => riding_a_horse
# in top 5: riding_or_walking_with_horse/70.mp4 => ['taking_photos', 'feeding_a_horse', 'running', 'riding_a_horse', 'looking_through_a_telescope']
# in top 5: riding_or_walking_with_horse/67.mp4 => ['phoning', 'jumping', 'running', 'riding_a_horse', 'feeding_a_horse']
# correct: riding_or_walking_with_horse/72.mp4 => riding_a_horse
# correct: riding_or_walking_with_horse/49.mp4 => riding_a_horse
# in top 5: riding_or_walking_with_horse/62.mp4 => ['shooting_an_arrow', 'fishing', 'riding_a_horse', 'walking_the_dog', 'feeding_a_horse']
# correct: riding_or_walking_with_horse/40.mp4 => riding_a_horse
# correct: riding_or_walking_with_horse/18.mp4 => riding_a_horse
# correct: riding_or_walking_with_horse/37.mp4 => riding_a_horse
# correct: riding_or_walking_with_horse/47.mp4 => riding_a_horse
# correct: riding_or_walking_with_horse/86.mp4 => riding_a_horse
# correct: riding_or_walking_with_horse/4.mp4 => riding_a_horse
# correct: riding_or_walking_with_horse/66.mp4 => riding_a_horse
# correct: riding_or_walking_with_horse/71.mp4 => riding_a_horse
# correct: riding_or_walking_with_horse/36.mp4 => riding_a_horse
# in top 5: using_computer/17.mp4 => ['looking_through_a_microscope', 'brushing_teeth', 'using_a_computer', 'reading', 'writing_on_a_book']
# wrong: using_computer/32.mp4 => watching_TV
# correct: using_computer/30.mp4 => using_a_computer
# correct: using_computer/29.mp4 => using_a_computer
# correct: using_computer/38.mp4 => using_a_computer
# correct: using_computer/57.mp4 => using_a_computer
# correct: using_computer/46.mp4 => using_a_computer
# correct: using_computer/63.mp4 => using_a_computer
# correct: using_computer/8.mp4 => using_a_computer
# wrong: using_computer/5.mp4 => writing_on_a_board
# correct: using_computer/77.mp4 => using_a_computer
# correct: using_computer/54.mp4 => using_a_computer
# correct: using_computer/65.mp4 => using_a_computer
# correct: using_computer/2.mp4 => using_a_computer
# in top 5: using_computer/12.mp4 => ['writing_on_a_book', 'reading', 'watching_TV', 'using_a_computer', 'writing_on_a_board']
# correct: using_computer/39.mp4 => using_a_computer
# correct: using_computer/42.mp4 => using_a_computer
# correct: using_computer/16.mp4 => using_a_computer
# correct: using_computer/79.mp4 => using_a_computer
# in top 5: using_computer/58.mp4 => ['reading', 'writing_on_a_book', 'smoking', 'using_a_computer', 'waving_hands']
# in top 5: using_computer/80.mp4 => ['writing_on_a_book', 'looking_through_a_microscope', 'writing_on_a_board', 'using_a_computer', 'watching_TV']
# correct: using_computer/55.mp4 => using_a_computer
# correct: using_computer/85.mp4 => using_a_computer
# in top 5: using_computer/73.mp4 => ['looking_through_a_microscope', 'reading', 'using_a_computer', 'writing_on_a_board', 'writing_on_a_book']
# correct: using_computer/78.mp4 => using_a_computer
# correct: using_computer/87.mp4 => using_a_computer
# correct: using_computer/3.mp4 => using_a_computer
# in top 5: using_computer/14.mp4 => ['writing_on_a_book', 'reading', 'writing_on_a_board', 'using_a_computer', 'watching_TV']
# correct: using_computer/76.mp4 => using_a_computer
# correct: using_computer/41.mp4 => using_a_computer
# correct: using_computer/43.mp4 => using_a_computer
# correct: using_computer/50.mp4 => using_a_computer
# correct: using_computer/60.mp4 => using_a_computer
# correct: using_computer/89.mp4 => using_a_computer
# correct: using_computer/15.mp4 => using_a_computer
# in top 5: using_computer/64.mp4 => ['writing_on_a_book', 'using_a_computer', 'writing_on_a_board', 'watching_TV', 'looking_through_a_microscope']
# correct: using_computer/61.mp4 => using_a_computer
# correct: using_computer/11.mp4 => using_a_computer
# in top 5: using_computer/83.mp4 => ['reading', 'texting_message', 'using_a_computer', 'writing_on_a_board', 'writing_on_a_book']
# correct: using_computer/20.mp4 => using_a_computer
# correct: using_computer/59.mp4 => using_a_computer
# correct: using_computer/7.mp4 => using_a_computer
# correct: using_computer/44.mp4 => using_a_computer
# correct: using_computer/81.mp4 => using_a_computer
# correct: using_computer/88.mp4 => using_a_computer
# correct: using_computer/1.mp4 => using_a_computer
# correct: using_computer/35.mp4 => using_a_computer
# in top 5: using_computer/31.mp4 => ['phoning', 'applauding', 'waving_hands', 'using_a_computer', 'writing_on_a_board']
# correct: using_computer/82.mp4 => using_a_computer
# correct: using_computer/53.mp4 => using_a_computer
# correct: using_computer/9.mp4 => using_a_computer
# correct: using_computer/34.mp4 => using_a_computer
# correct: using_computer/26.mp4 => using_a_computer
# correct: using_computer/84.mp4 => using_a_computer
# correct: using_computer/51.mp4 => using_a_computer
# correct: using_computer/28.mp4 => using_a_computer
# correct: using_computer/56.mp4 => using_a_computer
# correct: using_computer/90.mp4 => using_a_computer
# correct: using_computer/19.mp4 => using_a_computer
# correct: using_computer/27.mp4 => using_a_computer
# in top 5: using_computer/21.mp4 => ['waving_hands', 'watching_TV', 'looking_through_a_microscope', 'using_a_computer', 'writing_on_a_board']
# correct: using_computer/10.mp4 => using_a_computer
# in top 5: using_computer/52.mp4 => ['writing_on_a_book', 'reading', 'writing_on_a_board', 'using_a_computer', 'watching_TV']
# wrong: using_computer/33.mp4 => pushing_a_cart
# correct: using_computer/13.mp4 => using_a_computer
# correct: using_computer/91.mp4 => using_a_computer
# correct: using_computer/6.mp4 => using_a_computer
# in top 5: using_computer/67.mp4 => ['cleaning_the_floor', 'taking_photos', 'phoning', 'using_a_computer', 'looking_through_a_microscope']
# in top 5: using_computer/49.mp4 => ['looking_through_a_microscope', 'using_a_computer', 'texting_message', 'taking_photos', 'writing_on_a_board']
# correct: using_computer/62.mp4 => using_a_computer
# correct: using_computer/40.mp4 => using_a_computer
# correct: using_computer/18.mp4 => using_a_computer
# correct: using_computer/37.mp4 => using_a_computer
# correct: using_computer/47.mp4 => using_a_computer
# correct: using_computer/86.mp4 => using_a_computer
# correct: using_computer/4.mp4 => using_a_computer
# correct: using_computer/66.mp4 => using_a_computer
# correct: using_computer/71.mp4 => using_a_computer
# correct: using_computer/36.mp4 => using_a_computer
# correct: riding_a_bike/32.mp4 => riding_a_bike
# correct: riding_a_bike/30.mp4 => riding_a_bike
# correct: riding_a_bike/29.mp4 => riding_a_bike
# correct: riding_a_bike/38.mp4 => riding_a_bike
# correct: riding_a_bike/57.mp4 => riding_a_bike
# in top 5: riding_a_bike/46.mp4 => ['pushing_a_cart', 'writing_on_a_board', 'riding_a_bike', 'running', 'fixing_a_bike']
# correct: riding_a_bike/63.mp4 => riding_a_bike
# in top 5: riding_a_bike/8.mp4 => ['fishing', 'throwing_frisby', 'looking_through_a_telescope', 'riding_a_bike', 'running']
# in top 5: riding_a_bike/5.mp4 => ['throwing_frisby', 'running', 'riding_a_bike', 'taking_photos', 'pushing_a_cart']
# correct: riding_a_bike/69.mp4 => riding_a_bike
# correct: riding_a_bike/77.mp4 => riding_a_bike
# correct: riding_a_bike/54.mp4 => riding_a_bike
# correct: riding_a_bike/65.mp4 => riding_a_bike
# correct: riding_a_bike/12.mp4 => riding_a_bike
# correct: riding_a_bike/39.mp4 => riding_a_bike
# correct: riding_a_bike/42.mp4 => riding_a_bike
# wrong: riding_a_bike/79.mp4 => using_a_computer
# correct: riding_a_bike/58.mp4 => riding_a_bike
# correct: riding_a_bike/80.mp4 => riding_a_bike
# correct: riding_a_bike/55.mp4 => riding_a_bike
# correct: riding_a_bike/85.mp4 => riding_a_bike
# correct: riding_a_bike/73.mp4 => riding_a_bike
# correct: riding_a_bike/78.mp4 => riding_a_bike
# correct: riding_a_bike/87.mp4 => riding_a_bike
# in top 5: riding_a_bike/3.mp4 => ['walking_the_dog', 'waving_hands', 'fishing', 'riding_a_bike', 'running']
# correct: riding_a_bike/76.mp4 => riding_a_bike
# correct: riding_a_bike/41.mp4 => riding_a_bike
# correct: riding_a_bike/43.mp4 => riding_a_bike
# correct: riding_a_bike/50.mp4 => riding_a_bike
# correct: riding_a_bike/92.mp4 => riding_a_bike
# in top 5: riding_a_bike/60.mp4 => ['washing_dishes', 'looking_through_a_telescope', 'waving_hands', 'riding_a_bike', 'smoking']
# correct: riding_a_bike/89.mp4 => riding_a_bike
# in top 5: riding_a_bike/64.mp4 => ['applauding', 'looking_through_a_telescope', 'waving_hands', 'riding_a_bike', 'pushing_a_cart']
# correct: riding_a_bike/48.mp4 => riding_a_bike
# correct: riding_a_bike/61.mp4 => riding_a_bike
# correct: riding_a_bike/11.mp4 => riding_a_bike
# in top 5: riding_a_bike/83.mp4 => ['washing_dishes', 'riding_a_bike', 'fixing_a_car', 'fixing_a_bike', 'cooking']
# correct: riding_a_bike/68.mp4 => riding_a_bike
# wrong: riding_a_bike/20.mp4 => climbing
# correct: riding_a_bike/59.mp4 => riding_a_bike
# in top 5: riding_a_bike/7.mp4 => ['fishing', 'looking_through_a_telescope', 'pushing_a_cart', 'riding_a_bike', 'running']
# correct: riding_a_bike/44.mp4 => riding_a_bike
# correct: riding_a_bike/81.mp4 => riding_a_bike
# correct: riding_a_bike/88.mp4 => riding_a_bike
# correct: riding_a_bike/45.mp4 => riding_a_bike
# correct: riding_a_bike/1.mp4 => riding_a_bike
# correct: riding_a_bike/35.mp4 => riding_a_bike
# ...
# correct: cleaning_floor/80.mp4 => cleaning_the_floor
# correct: cleaning_floor/55.mp4 => cleaning_the_floor
# correct: cleaning_floor/85.mp4 => cleaning_the_floor
# wrong: cleaning_floor/73.mp4 => cutting_vegetables
# correct: cleaning_floor/78.mp4 => cleaning_the_floor
# correct: cleaning_floor/87.mp4 => cleaning_the_floor
# correct: cleaning_floor/3.mp4 => cleaning_the_floor
# correct: cleaning_floor/14.mp4 => cleaning_the_floor
# in top 5: cleaning_floor/76.mp4 => ['smoking', 'cutting_vegetables', 'brushing_teeth', 'cleaning_the_floor', 'washing_dishes']
# correct: cleaning_floor/41.mp4 => cleaning_the_floor
# correct: cleaning_floor/43.mp4 => cleaning_the_floor
# correct: cleaning_floor/50.mp4 => cleaning_the_floor
# correct: cleaning_floor/60.mp4 => cleaning_the_floor
# correct: cleaning_floor/89.mp4 => cleaning_the_floor
# correct: cleaning_floor/15.mp4 => cleaning_the_floor
# correct: cleaning_floor/64.mp4 => cleaning_the_floor
# correct: cleaning_floor/48.mp4 => cleaning_the_floor
# correct: cleaning_floor/61.mp4 => cleaning_the_floor
# in top 5: cleaning_floor/11.mp4 => ['looking_through_a_microscope', 'cleaning_the_floor', 'drinking', 'writing_on_a_board', 'looking_through_a_telescope']
# correct: cleaning_floor/83.mp4 => cleaning_the_floor
# in top 5: cleaning_floor/68.mp4 => ['cutting_vegetables', 'pouring_liquid', 'cleaning_the_floor', 'washing_dishes', 'drinking']
# correct: cleaning_floor/59.mp4 => cleaning_the_floor
# correct: cleaning_floor/7.mp4 => cleaning_the_floor
# correct: cleaning_floor/44.mp4 => cleaning_the_floor
# wrong: cleaning_floor/81.mp4 => pushing_a_cart
# in top 5: cleaning_floor/88.mp4 => ['walking_the_dog', 'fixing_a_bike', 'reading', 'cleaning_the_floor', 'looking_through_a_microscope']
# correct: cleaning_floor/45.mp4 => cleaning_the_floor
# correct: cleaning_floor/1.mp4 => cleaning_the_floor
# correct: cleaning_floor/35.mp4 => cleaning_the_floor
# correct: cleaning_floor/31.mp4 => cleaning_the_floor
# correct: cleaning_floor/82.mp4 => cleaning_the_floor
# correct: cleaning_floor/53.mp4 => cleaning_the_floor
# correct: cleaning_floor/9.mp4 => cleaning_the_floor
# correct: cleaning_floor/34.mp4 => cleaning_the_floor
# correct: cleaning_floor/26.mp4 => cleaning_the_floor
# correct: cleaning_floor/84.mp4 => cleaning_the_floor
# correct: cleaning_floor/51.mp4 => cleaning_the_floor
# correct: cleaning_floor/28.mp4 => cleaning_the_floor
# wrong: cleaning_floor/56.mp4 => writing_on_a_board
# wrong: cleaning_floor/90.mp4 => applauding
# correct: cleaning_floor/75.mp4 => cleaning_the_floor
# correct: cleaning_floor/27.mp4 => cleaning_the_floor
# correct: cleaning_floor/10.mp4 => cleaning_the_floor
# correct: cleaning_floor/74.mp4 => cleaning_the_floor
# correct: cleaning_floor/33.mp4 => cleaning_the_floor
# correct: cleaning_floor/13.mp4 => cleaning_the_floor
# wrong: cleaning_floor/91.mp4 => looking_through_a_microscope
# correct: cleaning_floor/6.mp4 => cleaning_the_floor
# wrong: cleaning_floor/70.mp4 => drinking
# correct: cleaning_floor/67.mp4 => cleaning_the_floor
# correct: cleaning_floor/72.mp4 => cleaning_the_floor
# in top 5: cleaning_floor/49.mp4 => ['reading', 'jumping', 'cutting_vegetables', 'cleaning_the_floor', 'pushing_a_cart']
# correct: cleaning_floor/62.mp4 => cleaning_the_floor
# correct: cleaning_floor/40.mp4 => cleaning_the_floor
# correct: cleaning_floor/18.mp4 => cleaning_the_floor
# correct: cleaning_floor/37.mp4 => cleaning_the_floor
# in top 5: cleaning_floor/47.mp4 => ['running', 'waving_hands', 'fishing', 'cleaning_the_floor', 'pushing_a_cart']
# correct: cleaning_floor/86.mp4 => cleaning_the_floor
# correct: cleaning_floor/4.mp4 => cleaning_the_floor
# correct: cleaning_floor/36.mp4 => cleaning_the_floor
# wrong: smoking/32.mp4 => writing_on_a_board
# in top 5: smoking/30.mp4 => ['drinking', 'texting_message', 'applauding', 'smoking', 'writing_on_a_board']
# in top 5: smoking/29.mp4 => ['smoking', 'applauding', 'taking_photos', 'drinking', 'brushing_teeth']
# correct: smoking/38.mp4 => smoking
# correct: smoking/57.mp4 => smoking
# in top 5: smoking/46.mp4 => ['texting_message', 'brushing_teeth', 'writing_on_a_board', 'smoking', 'taking_photos']
# in top 5: smoking/63.mp4 => ['brushing_teeth', 'smoking', 'waving_hands', 'applauding', 'watching_TV']
# in top 5: smoking/69.mp4 => ['taking_photos', 'smoking', 'writing_on_a_book', 'waving_hands', 'texting_message']
# wrong: smoking/54.mp4 => writing_on_a_board
# in top 5: smoking/12.mp4 => ['waving_hands', 'brushing_teeth', 'writing_on_a_book', 'smoking', 'texting_message']
# wrong: smoking/39.mp4 => writing_on_a_board
# in top 5: smoking/42.mp4 => ['cooking', 'smoking', 'waving_hands', 'applauding', 'blowing_bubbles']
# in top 5: smoking/58.mp4 => ['blowing_bubbles', 'drinking', 'texting_message', 'smoking', 'brushing_teeth']
# wrong: smoking/55.mp4 => taking_photos
# in top 5: smoking/73.mp4 => ['smoking', 'looking_through_a_microscope', 'cutting_vegetables', 'reading', 'texting_message']
# wrong: smoking/14.mp4 => drinking
# wrong: smoking/76.mp4 => applauding
# in top 5: smoking/60.mp4 => ['brushing_teeth', 'texting_message', 'smoking', 'applauding', 'writing_on_a_board']
# in top 5: smoking/15.mp4 => ['walking_the_dog', 'phoning', 'waving_hands', 'smoking', 'running']
# wrong: smoking/64.mp4 => applauding
# wrong: smoking/61.mp4 => writing_on_a_board
# wrong: smoking/11.mp4 => taking_photos
# wrong: smoking/59.mp4 => writing_on_a_board
# wrong: smoking/44.mp4 => applauding
# in top 5: smoking/35.mp4 => ['phoning', 'looking_through_a_microscope', 'pouring_liquid', 'smoking', 'applauding']
# correct: smoking/31.mp4 => smoking
# in top 5: smoking/24.mp4 => ['waving_hands', 'drinking', 'smoking', 'applauding', 'brushing_teeth']
# in top 5: smoking/9.mp4 => ['writing_on_a_board', 'smoking', 'drinking', 'brushing_teeth', 'texting_message']
# correct: smoking/34.mp4 => smoking
# correct: smoking/26.mp4 => smoking
# in top 5: smoking/51.mp4 => ['writing_on_a_book', 'drinking', 'applauding', 'smoking', 'brushing_teeth']
# in top 5: smoking/56.mp4 => ['texting_message', 'brushing_teeth', 'cutting_trees', 'smoking', 'drinking']
# wrong: smoking/22.mp4 => playing_violin
# in top 5: smoking/25.mp4 => ['texting_message', 'waving_hands', 'smoking', 'brushing_teeth', 'applauding']
# in top 5: smoking/75.mp4 => ['texting_message', 'waving_hands', 'smoking', 'gardening', 'writing_on_a_board']
# wrong: smoking/27.mp4 => brushing_teeth
# wrong: smoking/10.mp4 => waving_hands
# wrong: smoking/74.mp4 => writing_on_a_book
# in top 5: smoking/33.mp4 => ['looking_through_a_microscope', 'writing_on_a_board', 'brushing_teeth', 'smoking', 'applauding']
# in top 5: smoking/23.mp4 => ['writing_on_a_book', 'brushing_teeth', 'texting_message', 'smoking', 'writing_on_a_board']
# wrong: smoking/13.mp4 => drinking
# in top 5: smoking/6.mp4 => ['applauding', 'smoking', 'pouring_liquid', 'waving_hands', 'drinking']
# correct: smoking/67.mp4 => smoking
# wrong: smoking/49.mp4 => applauding
# wrong: smoking/40.mp4 => brushing_teeth
# in top 5: smoking/47.mp4 => ['brushing_teeth', 'writing_on_a_book', 'waving_hands', 'smoking', 'applauding']
# wrong: smoking/66.mp4 => waving_hands
# in top 5: smoking/36.mp4 => ['drinking', 'texting_message', 'writing_on_a_book', 'smoking', 'brushing_teeth']
# in top 5: pushing_cart/17.mp4 => ['climbing', 'writing_on_a_board', 'cleaning_the_floor', 'pushing_a_cart', 'waving_hands']
# correct: pushing_cart/32.mp4 => pushing_a_cart
# correct: pushing_cart/30.mp4 => pushing_a_cart
# in top 5: pushing_cart/29.mp4 => ['riding_a_bike', 'writing_on_a_board', 'cleaning_the_floor', 'pushing_a_cart', 'watching_TV']
# correct: pushing_cart/38.mp4 => pushing_a_cart
# in top 5: pushing_cart/57.mp4 => ['waving_hands', 'jumping', 'pushing_a_cart', 'brushing_teeth', 'cleaning_the_floor']
# correct: pushing_cart/46.mp4 => pushing_a_cart
# correct: pushing_cart/63.mp4 => pushing_a_cart
# correct: pushing_cart/8.mp4 => pushing_a_cart
# correct: pushing_cart/5.mp4 => pushing_a_cart
# correct: pushing_cart/69.mp4 => pushing_a_cart
# correct: pushing_cart/77.mp4 => pushing_a_cart
# in top 5: pushing_cart/54.mp4 => ['pushing_a_cart', 'jumping', 'running', 'writing_on_a_board', 'cleaning_the_floor']
# in top 5: pushing_cart/65.mp4 => ['gardening', 'blowing_bubbles', 'washing_dishes', 'pushing_a_cart', 'waving_hands']
# correct: pushing_cart/2.mp4 => pushing_a_cart
# correct: pushing_cart/12.mp4 => pushing_a_cart
# in top 5: pushing_cart/42.mp4 => ['taking_photos', 'pushing_a_cart', 'waving_hands', 'running', 'cleaning_the_floor']
# correct: pushing_cart/16.mp4 => pushing_a_cart
# correct: pushing_cart/79.mp4 => pushing_a_cart
# wrong: pushing_cart/58.mp4 => cleaning_the_floor
# wrong: pushing_cart/80.mp4 => writing_on_a_board
# wrong: pushing_cart/55.mp4 => cleaning_the_floor
# correct: pushing_cart/85.mp4 => pushing_a_cart
# correct: pushing_cart/73.mp4 => pushing_a_cart
# correct: pushing_cart/78.mp4 => pushing_a_cart
# correct: pushing_cart/87.mp4 => pushing_a_cart
# correct: pushing_cart/3.mp4 => pushing_a_cart
# in top 5: pushing_cart/14.mp4 => ['brushing_teeth', 'climbing', 'waving_hands', 'pushing_a_cart', 'cleaning_the_floor']
# wrong: pushing_cart/76.mp4 => cleaning_the_floor
# correct: pushing_cart/41.mp4 => pushing_a_cart
# in top 5: pushing_cart/43.mp4 => ['cutting_vegetables', 'watching_TV', 'riding_a_bike', 'pushing_a_cart', 'cleaning_the_floor']
# correct: pushing_cart/50.mp4 => pushing_a_cart
# correct: pushing_cart/60.mp4 => pushing_a_cart
# correct: pushing_cart/89.mp4 => pushing_a_cart
# correct: pushing_cart/15.mp4 => pushing_a_cart
# correct: pushing_cart/64.mp4 => pushing_a_cart
# correct: pushing_cart/48.mp4 => pushing_a_cart
# in top 5: pushing_cart/61.mp4 => ['cooking', 'pushing_a_cart', 'riding_a_bike', 'blowing_bubbles', 'running']
# correct: pushing_cart/11.mp4 => pushing_a_cart
# correct: pushing_cart/83.mp4 => pushing_a_cart
# correct: pushing_cart/68.mp4 => pushing_a_cart
# in top 5: pushing_cart/59.mp4 => ['running', 'fishing', 'looking_through_a_telescope', 'pushing_a_cart', 'riding_a_bike']
# correct: pushing_cart/7.mp4 => pushing_a_cart
# in top 5: pushing_cart/81.mp4 => ['watching_TV', 'cutting_vegetables', 'waving_hands', 'pushing_a_cart', 'cleaning_the_floor']
# correct: pushing_cart/88.mp4 => pushing_a_cart
# correct: pushing_cart/45.mp4 => pushing_a_cart
# in top 5: pushing_cart/1.mp4 => ['watching_TV', 'reading', 'using_a_computer', 'pushing_a_cart', 'cleaning_the_floor']
# correct: pushing_cart/35.mp4 => pushing_a_cart
# correct: pushing_cart/31.mp4 => pushing_a_cart
# correct: pushing_cart/24.mp4 => pushing_a_cart
# in top 5: pushing_cart/82.mp4 => ['running', 'smoking', 'taking_photos', 'pushing_a_cart', 'cleaning_the_floor']
# correct: pushing_cart/53.mp4 => pushing_a_cart
# wrong: pushing_cart/9.mp4 => writing_on_a_board
# correct: pushing_cart/34.mp4 => pushing_a_cart
# wrong: pushing_cart/26.mp4 => playing_violin
# correct: pushing_cart/84.mp4 => pushing_a_cart
# correct: pushing_cart/51.mp4 => pushing_a_cart
# correct: pushing_cart/28.mp4 => pushing_a_cart
# correct: pushing_cart/56.mp4 => pushing_a_cart
# correct: pushing_cart/90.mp4 => pushing_a_cart
# correct: pushing_cart/25.mp4 => pushing_a_cart
# wrong: pushing_cart/75.mp4 => writing_on_a_board
# correct: pushing_cart/27.mp4 => pushing_a_cart
# correct: pushing_cart/10.mp4 => pushing_a_cart
# correct: pushing_cart/52.mp4 => pushing_a_cart
# correct: pushing_cart/74.mp4 => pushing_a_cart
# in top 5: pushing_cart/33.mp4 => ['waving_hands', 'watching_TV', 'jumping', 'pushing_a_cart', 'cleaning_the_floor']
# wrong: pushing_cart/23.mp4 => watching_TV
# correct: pushing_cart/13.mp4 => pushing_a_cart
# in top 5: pushing_cart/91.mp4 => ['writing_on_a_board', 'taking_photos', 'watching_TV', 'pushing_a_cart', 'applauding']
# correct: pushing_cart/6.mp4 => pushing_a_cart
# correct: pushing_cart/70.mp4 => pushing_a_cart
# correct: pushing_cart/67.mp4 => pushing_a_cart
# in top 5: pushing_cart/72.mp4 => ['pouring_liquid', 'writing_on_a_board', 'watching_TV', 'pushing_a_cart', 'cleaning_the_floor']
# wrong: pushing_cart/49.mp4 => writing_on_a_board
# correct: pushing_cart/62.mp4 => pushing_a_cart
# wrong: pushing_cart/40.mp4 => phoning
# correct: pushing_cart/37.mp4 => pushing_a_cart
# correct: pushing_cart/47.mp4 => pushing_a_cart
# correct: pushing_cart/86.mp4 => pushing_a_cart
# correct: pushing_cart/4.mp4 => pushing_a_cart
# correct: pushing_cart/66.mp4 => pushing_a_cart
# in top 5: pushing_cart/71.mp4 => ['washing_dishes', 'riding_a_bike', 'pushing_a_cart', 'brushing_teeth', 'cleaning_the_floor']
# in top 5: pushing_cart/36.mp4 => ['writing_on_a_board', 'cleaning_the_floor', 'climbing', 'pushing_a_cart', 'waving_hands']
# correct: playing_guitar/32.mp4 => playing_guitar
# correct: playing_guitar/30.mp4 => playing_guitar
# correct: playing_guitar/29.mp4 => playing_guitar
# correct: playing_guitar/38.mp4 => playing_guitar
# correct: playing_guitar/57.mp4 => playing_guitar
# wrong: playing_guitar/46.mp4 => writing_on_a_board
# correct: playing_guitar/63.mp4 => playing_guitar
# correct: playing_guitar/8.mp4 => playing_guitar
# correct: playing_guitar/5.mp4 => playing_guitar
# correct: playing_guitar/69.mp4 => playing_guitar
# correct: playing_guitar/77.mp4 => playing_guitar
# correct: playing_guitar/54.mp4 => playing_guitar
# correct: playing_guitar/65.mp4 => playing_guitar
# correct: playing_guitar/2.mp4 => playing_guitar
# correct: playing_guitar/12.mp4 => playing_guitar
# correct: playing_guitar/42.mp4 => playing_guitar
# correct: playing_guitar/79.mp4 => playing_guitar
# correct: playing_guitar/80.mp4 => playing_guitar
# correct: playing_guitar/55.mp4 => playing_guitar
# correct: playing_guitar/85.mp4 => playing_guitar
# in top 5: playing_guitar/73.mp4 => ['phoning', 'playing_guitar', 'walking_the_dog', 'writing_on_a_board', 'applauding']
# correct: playing_guitar/78.mp4 => playing_guitar
# correct: playing_guitar/3.mp4 => playing_guitar
# correct: playing_guitar/76.mp4 => playing_guitar
# correct: playing_guitar/41.mp4 => playing_guitar
# correct: playing_guitar/50.mp4 => playing_guitar
# correct: playing_guitar/60.mp4 => playing_guitar
# correct: playing_guitar/15.mp4 => playing_guitar
# correct: playing_guitar/48.mp4 => playing_guitar
# correct: playing_guitar/61.mp4 => playing_guitar
# correct: playing_guitar/11.mp4 => playing_guitar
# correct: playing_guitar/83.mp4 => playing_guitar
# correct: playing_guitar/68.mp4 => playing_guitar
# correct: playing_guitar/59.mp4 => playing_guitar
# correct: playing_guitar/7.mp4 => playing_guitar
# correct: playing_guitar/44.mp4 => playing_guitar
# correct: playing_guitar/81.mp4 => playing_guitar
# correct: playing_guitar/45.mp4 => playing_guitar
# correct: playing_guitar/1.mp4 => playing_guitar
# correct: playing_guitar/35.mp4 => playing_guitar
# wrong: playing_guitar/31.mp4 => brushing_teeth
# correct: playing_guitar/82.mp4 => playing_guitar
# correct: playing_guitar/53.mp4 => playing_guitar
# correct: playing_guitar/9.mp4 => playing_guitar
# in top 5: playing_guitar/34.mp4 => ['cutting_trees', 'gardening', 'blowing_bubbles', 'playing_guitar', 'writing_on_a_book']
# wrong: playing_guitar/26.mp4 => looking_through_a_telescope
# correct: playing_guitar/84.mp4 => playing_guitar
# correct: playing_guitar/51.mp4 => playing_guitar
# correct: playing_guitar/28.mp4 => playing_guitar
# correct: playing_guitar/56.mp4 => playing_guitar
# correct: playing_guitar/27.mp4 => playing_guitar
# in top 5: playing_guitar/10.mp4 => ['looking_through_a_microscope', 'applauding', 'waving_hands', 'playing_guitar', 'writing_on_a_board']
# correct: playing_guitar/52.mp4 => playing_guitar
# correct: playing_guitar/74.mp4 => playing_guitar
# correct: playing_guitar/33.mp4 => playing_guitar
# correct: playing_guitar/13.mp4 => playing_guitar
# correct: playing_guitar/6.mp4 => playing_guitar
# correct: playing_guitar/70.mp4 => playing_guitar
# correct: playing_guitar/67.mp4 => playing_guitar
# correct: playing_guitar/72.mp4 => playing_guitar
# correct: playing_guitar/49.mp4 => playing_guitar
# correct: playing_guitar/62.mp4 => playing_guitar
# correct: playing_guitar/40.mp4 => playing_guitar
# correct: playing_guitar/37.mp4 => playing_guitar
# correct: playing_guitar/47.mp4 => playing_guitar
# correct: playing_guitar/86.mp4 => playing_guitar
# correct: playing_guitar/4.mp4 => playing_guitar
# correct: playing_guitar/66.mp4 => playing_guitar
# correct: playing_guitar/36.mp4 => playing_guitar

# %%
print(len(list(correct)))
print(len(list(in_top_5)))
print(len(list(incorrect)))
# Out:
# 702
# 295
# 181

# %%
results = { "correct" : correct, "in_top_5": in_top_5, "incorrect" : incorrect}

# %%
results
# Out:
# {'correct': {'drinking/38.mp4': 'drinking',
#   'drinking/77.mp4': 'drinking',
#   'drinking/2.mp4': 'drinking',
#   'drinking/12.mp4': 'drinking',
#   'drinking/39.mp4': 'drinking',
#   'drinking/79.mp4': 'drinking',
#   'drinking/55.mp4': 'drinking',
#   'drinking/73.mp4': 'drinking',
#   'drinking/76.mp4': 'drinking',
#   'drinking/60.mp4': 'drinking',
#   'drinking/89.mp4': 'drinking',
#   'drinking/15.mp4': 'drinking',
#   'drinking/11.mp4': 'drinking',
#   'drinking/59.mp4': 'drinking',
#   'drinking/45.mp4': 'drinking',
#   'drinking/31.mp4': 'drinking',
#   'drinking/9.mp4': 'drinking',
#   'drinking/84.mp4': 'drinking',
#   'drinking/51.mp4': 'drinking',
#   'drinking/28.mp4': 'drinking',
#   'drinking/75.mp4': 'drinking',
#   'drinking/74.mp4': 'drinking',
#   'drinking/13.mp4': 'drinking',
#   'drinking/6.mp4': 'drinking',
#   'drinking/62.mp4': 'drinking',
#   'drinking/86.mp4': 'drinking',
#   'texting/17.mp4': 'texting_message',
#   'texting/46.mp4': 'texting_message',
#   'texting/8.mp4': 'texting_message',
#   'texting/77.mp4': 'texting_message',
#   'texting/16.mp4': 'texting_message',
#   'texting/58.mp4': 'texting_message',
#   'texting/55.mp4': 'texting_message',
#   'texting/85.mp4': 'texting_message',
#   'texting/78.mp4': 'texting_message',
#   'texting/41.mp4': 'texting_message',
#   'texting/89.mp4': 'texting_message',
#   'texting/48.mp4': 'texting_message',
#   'texting/11.mp4': 'texting_message',
#   'texting/68.mp4': 'texting_message',
#   'texting/20.mp4': 'texting_message',
#   'texting/88.mp4': 'texting_message',
#   'texting/45.mp4': 'texting_message',
#   'texting/1.mp4': 'texting_message',
#   'texting/35.mp4': 'texting_message',
#   'texting/34.mp4': 'texting_message',
#   'texting/28.mp4': 'texting_message',
#   'texting/75.mp4': 'texting_message',
#   'texting/21.mp4': 'texting_message',
#   'texting/52.mp4': 'texting_message',
#   'texting/74.mp4': 'texting_message',
#   'texting/13.mp4': 'texting_message',
#   'texting/91.mp4': 'texting_message',
#   'texting/49.mp4': 'texting_message',
#   'texting/18.mp4': 'texting_message',
#   'texting/37.mp4': 'texting_message',
#   'texting/86.mp4': 'texting_message',
#   'texting/66.mp4': 'texting_message',
#   'texting/71.mp4': 'texting_message',
#   'playing_violin/32.mp4': 'playing_violin',
#   'playing_violin/57.mp4': 'playing_violin',
#   'playing_violin/46.mp4': 'playing_violin',
#   'playing_violin/63.mp4': 'playing_violin',
#   'playing_violin/5.mp4': 'playing_violin',
#   'playing_violin/69.mp4': 'playing_violin',
#   'playing_violin/77.mp4': 'playing_violin',
#   'playing_violin/54.mp4': 'playing_violin',
#   'playing_violin/65.mp4': 'playing_violin',
#   'playing_violin/12.mp4': 'playing_violin',
#   'playing_violin/42.mp4': 'playing_violin',
#   'playing_violin/58.mp4': 'playing_violin',
#   'playing_violin/80.mp4': 'playing_violin',
#   'playing_violin/55.mp4': 'playing_violin',
#   'playing_violin/73.mp4': 'playing_violin',
#   'playing_violin/78.mp4': 'playing_violin',
#   'playing_violin/3.mp4': 'playing_violin',
#   'playing_violin/76.mp4': 'playing_violin',
#   'playing_violin/41.mp4': 'playing_violin',
#   'playing_violin/50.mp4': 'playing_violin',
#   'playing_violin/92.mp4': 'playing_violin',
#   'playing_violin/60.mp4': 'playing_violin',
#   'playing_violin/15.mp4': 'playing_violin',
#   'playing_violin/64.mp4': 'playing_violin',
#   'playing_violin/48.mp4': 'playing_violin',
#   'playing_violin/61.mp4': 'playing_violin',
#   'playing_violin/11.mp4': 'playing_violin',
#   'playing_violin/83.mp4': 'playing_violin',
#   'playing_violin/68.mp4': 'playing_violin',
#   'playing_violin/59.mp4': 'playing_violin',
#   'playing_violin/7.mp4': 'playing_violin',
#   'playing_violin/81.mp4': 'playing_violin',
#   'playing_violin/88.mp4': 'playing_violin',
#   'playing_violin/1.mp4': 'playing_violin',
#   'playing_violin/35.mp4': 'playing_violin',
#   'playing_violin/31.mp4': 'playing_violin',
#   'playing_violin/24.mp4': 'playing_violin',
#   'playing_violin/82.mp4': 'playing_violin',
#   'playing_violin/53.mp4': 'playing_violin',
#   'playing_violin/9.mp4': 'playing_violin',
#   'playing_violin/26.mp4': 'playing_violin',
#   'playing_violin/51.mp4': 'playing_violin',
#   'playing_violin/28.mp4': 'playing_violin',
#   'playing_violin/56.mp4': 'playing_violin',
#   'playing_violin/22.mp4': 'playing_violin',
#   'playing_violin/90.mp4': 'playing_violin',
#   'playing_violin/25.mp4': 'playing_violin',
#   'playing_violin/27.mp4': 'playing_violin',
#   'playing_violin/10.mp4': 'playing_violin',
#   'playing_violin/52.mp4': 'playing_violin',
#   'playing_violin/74.mp4': 'playing_violin',
#   'playing_violin/33.mp4': 'playing_violin',
#   'playing_violin/13.mp4': 'playing_violin',
#   'playing_violin/91.mp4': 'playing_violin',
#   'playing_violin/6.mp4': 'playing_violin',
#   'playing_violin/67.mp4': 'playing_violin',
#   'playing_violin/72.mp4': 'playing_violin',
#   'playing_violin/49.mp4': 'playing_violin',
#   'playing_violin/62.mp4': 'playing_violin',
#   'playing_violin/40.mp4': 'playing_violin',
#   'playing_violin/47.mp4': 'playing_violin',
#   'playing_violin/4.mp4': 'playing_violin',
#   'playing_violin/66.mp4': 'playing_violin',
#   'playing_violin/36.mp4': 'playing_violin',
#   'washing_dishes/29.mp4': 'washing_dishes',
#   'washing_dishes/57.mp4': 'washing_dishes',
#   'washing_dishes/63.mp4': 'washing_dishes',
#   'washing_dishes/8.mp4': 'washing_dishes',
#   'washing_dishes/5.mp4': 'washing_dishes',
#   'washing_dishes/39.mp4': 'washing_dishes',
#   'washing_dishes/42.mp4': 'washing_dishes',
#   'washing_dishes/16.mp4': 'washing_dishes',
#   'washing_dishes/79.mp4': 'washing_dishes',
#   'washing_dishes/58.mp4': 'washing_dishes',
#   'washing_dishes/55.mp4': 'washing_dishes',
#   'washing_dishes/85.mp4': 'washing_dishes',
#   'washing_dishes/78.mp4': 'washing_dishes',
#   'washing_dishes/41.mp4': 'washing_dishes',
#   'washing_dishes/43.mp4': 'washing_dishes',
#   'washing_dishes/60.mp4': 'washing_dishes',
#   'washing_dishes/89.mp4': 'washing_dishes',
#   'washing_dishes/15.mp4': 'washing_dishes',
#   'washing_dishes/64.mp4': 'washing_dishes',
#   'washing_dishes/48.mp4': 'washing_dishes',
#   'washing_dishes/61.mp4': 'washing_dishes',
#   'washing_dishes/11.mp4': 'washing_dishes',
#   'washing_dishes/20.mp4': 'washing_dishes',
#   'washing_dishes/59.mp4': 'washing_dishes',
#   'washing_dishes/44.mp4': 'washing_dishes',
#   'washing_dishes/81.mp4': 'washing_dishes',
#   'washing_dishes/88.mp4': 'washing_dishes',
#   'washing_dishes/45.mp4': 'washing_dishes',
#   'washing_dishes/1.mp4': 'washing_dishes',
#   'washing_dishes/24.mp4': 'washing_dishes',
#   'washing_dishes/53.mp4': 'washing_dishes',
#   'washing_dishes/9.mp4': 'washing_dishes',
#   'washing_dishes/26.mp4': 'washing_dishes',
#   'washing_dishes/28.mp4': 'washing_dishes',
#   'washing_dishes/22.mp4': 'washing_dishes',
#   'washing_dishes/90.mp4': 'washing_dishes',
#   'washing_dishes/19.mp4': 'washing_dishes',
#   'washing_dishes/25.mp4': 'washing_dishes',
#   'washing_dishes/75.mp4': 'washing_dishes',
#   'washing_dishes/27.mp4': 'washing_dishes',
#   'washing_dishes/74.mp4': 'washing_dishes',
#   'washing_dishes/13.mp4': 'washing_dishes',
#   'washing_dishes/6.mp4': 'washing_dishes',
#   'washing_dishes/70.mp4': 'washing_dishes',
#   'washing_dishes/67.mp4': 'washing_dishes',
#   'washing_dishes/49.mp4': 'washing_dishes',
#   'washing_dishes/40.mp4': 'washing_dishes',
#   'washing_dishes/18.mp4': 'washing_dishes',
#   'washing_dishes/37.mp4': 'washing_dishes',
#   'washing_dishes/47.mp4': 'washing_dishes',
#   'washing_dishes/71.mp4': 'washing_dishes',
#   'washing_dishes/36.mp4': 'washing_dishes',
#   'walking_the_dog/32.mp4': 'walking_the_dog',
#   'walking_the_dog/30.mp4': 'walking_the_dog',
#   'walking_the_dog/29.mp4': 'walking_the_dog',
#   'walking_the_dog/46.mp4': 'walking_the_dog',
#   'walking_the_dog/5.mp4': 'walking_the_dog',
#   'walking_the_dog/77.mp4': 'walking_the_dog',
#   'walking_the_dog/54.mp4': 'walking_the_dog',
#   'walking_the_dog/2.mp4': 'walking_the_dog',
#   'walking_the_dog/39.mp4': 'walking_the_dog',
#   'walking_the_dog/42.mp4': 'walking_the_dog',
#   'walking_the_dog/16.mp4': 'walking_the_dog',
#   'walking_the_dog/41.mp4': 'walking_the_dog',
#   'walking_the_dog/43.mp4': 'walking_the_dog',
#   'walking_the_dog/50.mp4': 'walking_the_dog',
#   'walking_the_dog/64.mp4': 'walking_the_dog',
#   'walking_the_dog/83.mp4': 'walking_the_dog',
#   'walking_the_dog/68.mp4': 'walking_the_dog',
#   'walking_the_dog/7.mp4': 'walking_the_dog',
#   'walking_the_dog/81.mp4': 'walking_the_dog',
#   'walking_the_dog/88.mp4': 'walking_the_dog',
#   'walking_the_dog/45.mp4': 'walking_the_dog',
#   'walking_the_dog/26.mp4': 'walking_the_dog',
#   'walking_the_dog/56.mp4': 'walking_the_dog',
#   'walking_the_dog/19.mp4': 'walking_the_dog',
#   'walking_the_dog/10.mp4': 'walking_the_dog',
#   'walking_the_dog/52.mp4': 'walking_the_dog',
#   'walking_the_dog/74.mp4': 'walking_the_dog',
#   'walking_the_dog/70.mp4': 'walking_the_dog',
#   'walking_the_dog/95.mp4': 'walking_the_dog',
#   'walking_the_dog/62.mp4': 'walking_the_dog',
#   'walking_the_dog/18.mp4': 'walking_the_dog',
#   'walking_the_dog/94.mp4': 'walking_the_dog',
#   'walking_the_dog/4.mp4': 'walking_the_dog',
#   'walking_the_dog/66.mp4': 'walking_the_dog',
#   'walking_the_dog/36.mp4': 'walking_the_dog',
#   'reading_book/57.mp4': 'reading',
#   'reading_book/8.mp4': 'reading',
#   'reading_book/5.mp4': 'reading',
#   'reading_book/69.mp4': 'reading',
#   'reading_book/77.mp4': 'reading',
#   'reading_book/2.mp4': 'reading',
#   'reading_book/12.mp4': 'reading',
#   'reading_book/16.mp4': 'reading',
#   'reading_book/58.mp4': 'reading',
#   'reading_book/80.mp4': 'reading',
#   'reading_book/55.mp4': 'reading',
#   'reading_book/43.mp4': 'reading',
#   'reading_book/92.mp4': 'reading',
#   'reading_book/89.mp4': 'reading',
#   'reading_book/15.mp4': 'reading',
#   'reading_book/64.mp4': 'reading',
#   'reading_book/48.mp4': 'reading',
#   'reading_book/11.mp4': 'reading',
#   'reading_book/83.mp4': 'reading',
#   'reading_book/68.mp4': 'reading',
#   'reading_book/31.mp4': 'reading',
#   'reading_book/53.mp4': 'reading',
#   'reading_book/51.mp4': 'reading',
#   'reading_book/25.mp4': 'reading',
#   'reading_book/10.mp4': 'reading',
#   'reading_book/52.mp4': 'reading',
#   'reading_book/23.mp4': 'reading',
#   'reading_book/13.mp4': 'reading',
#   'reading_book/91.mp4': 'reading',
#   'reading_book/6.mp4': 'reading',
#   'reading_book/49.mp4': 'reading',
#   'reading_book/62.mp4': 'reading',
#   'reading_book/47.mp4': 'reading',
#   'reading_book/4.mp4': 'reading',
#   'reading_book/36.mp4': 'reading',
#   'riding_or_walking_with_horse/32.mp4': 'riding_a_horse',
#   'riding_or_walking_with_horse/29.mp4': 'riding_a_horse',
#   'riding_or_walking_with_horse/38.mp4': 'riding_a_horse',
#   'riding_or_walking_with_horse/57.mp4': 'riding_a_horse',
#   'riding_or_walking_with_horse/63.mp4': 'riding_a_horse',
#   'riding_or_walking_with_horse/8.mp4': 'riding_a_horse',
#   'riding_or_walking_with_horse/5.mp4': 'riding_a_horse',
#   'riding_or_walking_with_horse/69.mp4': 'riding_a_horse',
#   'riding_or_walking_with_horse/2.mp4': 'riding_a_horse',
#   'riding_or_walking_with_horse/12.mp4': 'riding_a_horse',
#   'riding_or_walking_with_horse/39.mp4': 'riding_a_horse',
#   'riding_or_walking_with_horse/42.mp4': 'riding_a_horse',
#   'riding_or_walking_with_horse/16.mp4': 'riding_a_horse',
#   'riding_or_walking_with_horse/79.mp4': 'riding_a_horse',
#   'riding_or_walking_with_horse/80.mp4': 'riding_a_horse',
#   'riding_or_walking_with_horse/55.mp4': 'riding_a_horse',
#   'riding_or_walking_with_horse/73.mp4': 'riding_a_horse',
#   'riding_or_walking_with_horse/78.mp4': 'riding_a_horse',
#   'riding_or_walking_with_horse/87.mp4': 'riding_a_horse',
#   'riding_or_walking_with_horse/3.mp4': 'riding_a_horse',
#   'riding_or_walking_with_horse/14.mp4': 'riding_a_horse',
#   'riding_or_walking_with_horse/76.mp4': 'riding_a_horse',
#   'riding_or_walking_with_horse/41.mp4': 'riding_a_horse',
#   'riding_or_walking_with_horse/43.mp4': 'riding_a_horse',
#   'riding_or_walking_with_horse/50.mp4': 'riding_a_horse',
#   'riding_or_walking_with_horse/15.mp4': 'riding_a_horse',
#   'riding_or_walking_with_horse/64.mp4': 'riding_a_horse',
#   'riding_or_walking_with_horse/48.mp4': 'riding_a_horse',
#   'riding_or_walking_with_horse/11.mp4': 'riding_a_horse',
#   'riding_or_walking_with_horse/83.mp4': 'riding_a_horse',
#   'riding_or_walking_with_horse/68.mp4': 'riding_a_horse',
#   'riding_or_walking_with_horse/20.mp4': 'riding_a_horse',
#   'riding_or_walking_with_horse/59.mp4': 'riding_a_horse',
#   'riding_or_walking_with_horse/7.mp4': 'riding_a_horse',
#   'riding_or_walking_with_horse/81.mp4': 'riding_a_horse',
#   'riding_or_walking_with_horse/88.mp4': 'riding_a_horse',
#   'riding_or_walking_with_horse/35.mp4': 'riding_a_horse',
#   'riding_or_walking_with_horse/53.mp4': 'riding_a_horse',
#   'riding_or_walking_with_horse/9.mp4': 'riding_a_horse',
#   'riding_or_walking_with_horse/34.mp4': 'riding_a_horse',
#   'riding_or_walking_with_horse/51.mp4': 'riding_a_horse',
#   'riding_or_walking_with_horse/28.mp4': 'riding_a_horse',
#   'riding_or_walking_with_horse/21.mp4': 'riding_a_horse',
#   'riding_or_walking_with_horse/52.mp4': 'riding_a_horse',
#   'riding_or_walking_with_horse/74.mp4': 'riding_a_horse',
#   'riding_or_walking_with_horse/23.mp4': 'riding_a_horse',
#   'riding_or_walking_with_horse/13.mp4': 'riding_a_horse',
#   'riding_or_walking_with_horse/6.mp4': 'riding_a_horse',
#   'riding_or_walking_with_horse/72.mp4': 'riding_a_horse',
#   'riding_or_walking_with_horse/49.mp4': 'riding_a_horse',
#   'riding_or_walking_with_horse/40.mp4': 'riding_a_horse',
#   'riding_or_walking_with_horse/18.mp4': 'riding_a_horse',
#   'riding_or_walking_with_horse/37.mp4': 'riding_a_horse',
#   'riding_or_walking_with_horse/47.mp4': 'riding_a_horse',
#   'riding_or_walking_with_horse/86.mp4': 'riding_a_horse',
#   'riding_or_walking_with_horse/4.mp4': 'riding_a_horse',
#   'riding_or_walking_with_horse/66.mp4': 'riding_a_horse',
#   'riding_or_walking_with_horse/71.mp4': 'riding_a_horse',
#   'riding_or_walking_with_horse/36.mp4': 'riding_a_horse',
#   'using_computer/30.mp4': 'using_a_computer',
#   'using_computer/29.mp4': 'using_a_computer',
#   'using_computer/38.mp4': 'using_a_computer',
#   'using_computer/57.mp4': 'using_a_computer',
#   'using_computer/46.mp4': 'using_a_computer',
#   'using_computer/63.mp4': 'using_a_computer',
#   'using_computer/8.mp4': 'using_a_computer',
#   'using_computer/77.mp4': 'using_a_computer',
#   'using_computer/54.mp4': 'using_a_computer',
#   'using_computer/65.mp4': 'using_a_computer',
#   'using_computer/2.mp4': 'using_a_computer',
#   'using_computer/39.mp4': 'using_a_computer',
#   'using_computer/42.mp4': 'using_a_computer',
#   'using_computer/16.mp4': 'using_a_computer',
#   'using_computer/79.mp4': 'using_a_computer',
#   'using_computer/55.mp4': 'using_a_computer',
#   'using_computer/85.mp4': 'using_a_computer',
#   'using_computer/78.mp4': 'using_a_computer',
#   'using_computer/87.mp4': 'using_a_computer',
#   'using_computer/3.mp4': 'using_a_computer',
#   'using_computer/76.mp4': 'using_a_computer',
#   'using_computer/41.mp4': 'using_a_computer',
#   'using_computer/43.mp4': 'using_a_computer',
#   'using_computer/50.mp4': 'using_a_computer',
#   'using_computer/60.mp4': 'using_a_computer',
#   'using_computer/89.mp4': 'using_a_computer',
#   'using_computer/15.mp4': 'using_a_computer',
#   'using_computer/61.mp4': 'using_a_computer',
#   'using_computer/11.mp4': 'using_a_computer',
#   'using_computer/20.mp4': 'using_a_computer',
#   'using_computer/59.mp4': 'using_a_computer',
#   'using_computer/7.mp4': 'using_a_computer',
#   'using_computer/44.mp4': 'using_a_computer',
#   'using_computer/81.mp4': 'using_a_computer',
#   'using_computer/88.mp4': 'using_a_computer',
#   'using_computer/1.mp4': 'using_a_computer',
#   'using_computer/35.mp4': 'using_a_computer',
#   'using_computer/82.mp4': 'using_a_computer',
#   'using_computer/53.mp4': 'using_a_computer',
#   'using_computer/9.mp4': 'using_a_computer',
#   'using_computer/34.mp4': 'using_a_computer',
#   'using_computer/26.mp4': 'using_a_computer',
#   'using_computer/84.mp4': 'using_a_computer',
#   'using_computer/51.mp4': 'using_a_computer',
#   'using_computer/28.mp4': 'using_a_computer',
#   'using_computer/56.mp4': 'using_a_computer',
#   'using_computer/90.mp4': 'using_a_computer',
#   'using_computer/19.mp4': 'using_a_computer',
#   'using_computer/27.mp4': 'using_a_computer',
#   'using_computer/10.mp4': 'using_a_computer',
#   'using_computer/13.mp4': 'using_a_computer',
#   'using_computer/91.mp4': 'using_a_computer',
#   'using_computer/6.mp4': 'using_a_computer',
#   'using_computer/62.mp4': 'using_a_computer',
#   'using_computer/40.mp4': 'using_a_computer',
#   'using_computer/18.mp4': 'using_a_computer',
#   'using_computer/37.mp4': 'using_a_computer',
#   'using_computer/47.mp4': 'using_a_computer',
#   'using_computer/86.mp4': 'using_a_computer',
#   'using_computer/4.mp4': 'using_a_computer',
#   'using_computer/66.mp4': 'using_a_computer',
#   'using_computer/71.mp4': 'using_a_computer',
#   'using_computer/36.mp4': 'using_a_computer',
#   'riding_a_bike/32.mp4': 'riding_a_bike',
#   'riding_a_bike/30.mp4': 'riding_a_bike',
#   'riding_a_bike/29.mp4': 'riding_a_bike',
#   'riding_a_bike/38.mp4': 'riding_a_bike',
#   'riding_a_bike/57.mp4': 'riding_a_bike',
#   'riding_a_bike/63.mp4': 'riding_a_bike',
#   'riding_a_bike/69.mp4': 'riding_a_bike',
#   'riding_a_bike/77.mp4': 'riding_a_bike',
#   'riding_a_bike/54.mp4': 'riding_a_bike',
#   'riding_a_bike/65.mp4': 'riding_a_bike',
#   'riding_a_bike/12.mp4': 'riding_a_bike',
#   'riding_a_bike/39.mp4': 'riding_a_bike',
#   'riding_a_bike/42.mp4': 'riding_a_bike',
#   'riding_a_bike/58.mp4': 'riding_a_bike',
#   'riding_a_bike/80.mp4': 'riding_a_bike',
#   'riding_a_bike/55.mp4': 'riding_a_bike',
#   'riding_a_bike/85.mp4': 'riding_a_bike',
#   'riding_a_bike/73.mp4': 'riding_a_bike',
#   'riding_a_bike/78.mp4': 'riding_a_bike',
#   'riding_a_bike/87.mp4': 'riding_a_bike',
#   'riding_a_bike/76.mp4': 'riding_a_bike',
#   'riding_a_bike/41.mp4': 'riding_a_bike',
#   'riding_a_bike/43.mp4': 'riding_a_bike',
#   'riding_a_bike/50.mp4': 'riding_a_bike',
#   'riding_a_bike/92.mp4': 'riding_a_bike',
#   'riding_a_bike/89.mp4': 'riding_a_bike',
#   'riding_a_bike/48.mp4': 'riding_a_bike',
#   'riding_a_bike/61.mp4': 'riding_a_bike',
#   'riding_a_bike/11.mp4': 'riding_a_bike',
#   'riding_a_bike/68.mp4': 'riding_a_bike',
#   'riding_a_bike/59.mp4': 'riding_a_bike',
#   'riding_a_bike/44.mp4': 'riding_a_bike',
#   'riding_a_bike/81.mp4': 'riding_a_bike',
#   'riding_a_bike/88.mp4': 'riding_a_bike',
#   'riding_a_bike/45.mp4': 'riding_a_bike',
#   'riding_a_bike/1.mp4': 'riding_a_bike',
#   'riding_a_bike/35.mp4': 'riding_a_bike',
#   'riding_a_bike/31.mp4': 'riding_a_bike',
#   'riding_a_bike/82.mp4': 'riding_a_bike',
#   'riding_a_bike/53.mp4': 'riding_a_bike',
#   'riding_a_bike/34.mp4': 'riding_a_bike',
#   'riding_a_bike/26.mp4': 'riding_a_bike',
#   'riding_a_bike/84.mp4': 'riding_a_bike',
#   'riding_a_bike/51.mp4': 'riding_a_bike',
#   'riding_a_bike/28.mp4': 'riding_a_bike',
#   'riding_a_bike/90.mp4': 'riding_a_bike',
#   'riding_a_bike/75.mp4': 'riding_a_bike',
#   'riding_a_bike/27.mp4': 'riding_a_bike',
#   'riding_a_bike/21.mp4': 'riding_a_bike',
#   'riding_a_bike/10.mp4': 'riding_a_bike',
#   'riding_a_bike/33.mp4': 'riding_a_bike',
#   'riding_a_bike/13.mp4': 'riding_a_bike',
#   'riding_a_bike/6.mp4': 'riding_a_bike',
#   'riding_a_bike/67.mp4': 'riding_a_bike',
#   'riding_a_bike/72.mp4': 'riding_a_bike',
#   'riding_a_bike/95.mp4': 'riding_a_bike',
#   'riding_a_bike/49.mp4': 'riding_a_bike',
#   'riding_a_bike/40.mp4': 'riding_a_bike',
#   'riding_a_bike/93.mp4': 'riding_a_bike',
#   'riding_a_bike/94.mp4': 'riding_a_bike',
#   'riding_a_bike/86.mp4': 'riding_a_bike',
#   'riding_a_bike/4.mp4': 'riding_a_bike',
#   'riding_a_bike/66.mp4': 'riding_a_bike',
#   'riding_a_bike/71.mp4': 'riding_a_bike',
#   'brushing_teeth/30.mp4': 'brushing_teeth',
#   'brushing_teeth/29.mp4': 'brushing_teeth',
#   'brushing_teeth/38.mp4': 'brushing_teeth',
#   'brushing_teeth/57.mp4': 'brushing_teeth',
#   'brushing_teeth/63.mp4': 'brushing_teeth',
#   'brushing_teeth/8.mp4': 'brushing_teeth',
#   'brushing_teeth/5.mp4': 'brushing_teeth',
#   'brushing_teeth/69.mp4': 'brushing_teeth',
#   'brushing_teeth/77.mp4': 'brushing_teeth',
#   'brushing_teeth/65.mp4': 'brushing_teeth',
#   'brushing_teeth/39.mp4': 'brushing_teeth',
#   'brushing_teeth/42.mp4': 'brushing_teeth',
#   'brushing_teeth/16.mp4': 'brushing_teeth',
#   'brushing_teeth/79.mp4': 'brushing_teeth',
#   'brushing_teeth/80.mp4': 'brushing_teeth',
#   'brushing_teeth/55.mp4': 'brushing_teeth',
#   'brushing_teeth/73.mp4': 'brushing_teeth',
#   'brushing_teeth/78.mp4': 'brushing_teeth',
#   'brushing_teeth/87.mp4': 'brushing_teeth',
#   'brushing_teeth/14.mp4': 'brushing_teeth',
#   'brushing_teeth/76.mp4': 'brushing_teeth',
#   'brushing_teeth/43.mp4': 'brushing_teeth',
#   'brushing_teeth/92.mp4': 'brushing_teeth',
#   'brushing_teeth/60.mp4': 'brushing_teeth',
#   'brushing_teeth/89.mp4': 'brushing_teeth',
#   'brushing_teeth/15.mp4': 'brushing_teeth',
#   'brushing_teeth/48.mp4': 'brushing_teeth',
#   'brushing_teeth/61.mp4': 'brushing_teeth',
#   'brushing_teeth/11.mp4': 'brushing_teeth',
#   'brushing_teeth/83.mp4': 'brushing_teeth',
#   'brushing_teeth/68.mp4': 'brushing_teeth',
#   'brushing_teeth/59.mp4': 'brushing_teeth',
#   'brushing_teeth/7.mp4': 'brushing_teeth',
#   'brushing_teeth/81.mp4': 'brushing_teeth',
#   'brushing_teeth/88.mp4': 'brushing_teeth',
#   'brushing_teeth/45.mp4': 'brushing_teeth',
#   'brushing_teeth/1.mp4': 'brushing_teeth',
#   'brushing_teeth/35.mp4': 'brushing_teeth',
#   'brushing_teeth/31.mp4': 'brushing_teeth',
#   'brushing_teeth/24.mp4': 'brushing_teeth',
#   'brushing_teeth/53.mp4': 'brushing_teeth',
#   'brushing_teeth/9.mp4': 'brushing_teeth',
#   'brushing_teeth/26.mp4': 'brushing_teeth',
#   'brushing_teeth/84.mp4': 'brushing_teeth',
#   'brushing_teeth/28.mp4': 'brushing_teeth',
#   'brushing_teeth/90.mp4': 'brushing_teeth',
#   'brushing_teeth/25.mp4': 'brushing_teeth',
#   'brushing_teeth/27.mp4': 'brushing_teeth',
#   'brushing_teeth/33.mp4': 'brushing_teeth',
#   'brushing_teeth/91.mp4': 'brushing_teeth',
#   'brushing_teeth/6.mp4': 'brushing_teeth',
#   'brushing_teeth/70.mp4': 'brushing_teeth',
#   'brushing_teeth/67.mp4': 'brushing_teeth',
#   'brushing_teeth/72.mp4': 'brushing_teeth',
#   'brushing_teeth/62.mp4': 'brushing_teeth',
#   'brushing_teeth/93.mp4': 'brushing_teeth',
#   'brushing_teeth/37.mp4': 'brushing_teeth',
#   'brushing_teeth/47.mp4': 'brushing_teeth',
#   'brushing_teeth/86.mp4': 'brushing_teeth',
#   'brushing_teeth/4.mp4': 'brushing_teeth',
#   'brushing_teeth/66.mp4': 'brushing_teeth',
#   'brushing_teeth/71.mp4': 'brushing_teeth',
#   'brushing_teeth/36.mp4': 'brushing_teeth',
#   'drinking_beer/29.mp4': 'drinking',
#   'drinking_beer/63.mp4': 'drinking',
#   'drinking_beer/65.mp4': 'drinking',
#   'drinking_beer/16.mp4': 'drinking',
#   'drinking_beer/55.mp4': 'drinking',
#   'drinking_beer/73.mp4': 'drinking',
#   'drinking_beer/3.mp4': 'drinking',
#   'drinking_beer/14.mp4': 'drinking',
#   'drinking_beer/43.mp4': 'drinking',
#   'drinking_beer/64.mp4': 'drinking',
#   'drinking_beer/20.mp4': 'drinking',
#   'drinking_beer/1.mp4': 'drinking',
#   'drinking_beer/82.mp4': 'drinking',
#   'drinking_beer/90.mp4': 'drinking',
#   'drinking_beer/19.mp4': 'drinking',
#   'drinking_beer/10.mp4': 'drinking',
#   'drinking_beer/13.mp4': 'drinking',
#   'drinking_beer/40.mp4': 'drinking',
#   'drinking_beer/18.mp4': 'drinking',
#   'drinking_beer/36.mp4': 'drinking',
#   'cleaning_floor/32.mp4': 'cleaning_the_floor',
#   'cleaning_floor/30.mp4': 'cleaning_the_floor',
#   'cleaning_floor/29.mp4': 'cleaning_the_floor',
#   'cleaning_floor/38.mp4': 'cleaning_the_floor',
#   'cleaning_floor/46.mp4': 'cleaning_the_floor',
#   'cleaning_floor/8.mp4': 'cleaning_the_floor',
#   'cleaning_floor/5.mp4': 'cleaning_the_floor',
#   'cleaning_floor/69.mp4': 'cleaning_the_floor',
#   'cleaning_floor/77.mp4': 'cleaning_the_floor',
#   'cleaning_floor/54.mp4': 'cleaning_the_floor',
#   'cleaning_floor/65.mp4': 'cleaning_the_floor',
#   'cleaning_floor/2.mp4': 'cleaning_the_floor',
#   'cleaning_floor/16.mp4': 'cleaning_the_floor',
#   'cleaning_floor/79.mp4': 'cleaning_the_floor',
#   'cleaning_floor/58.mp4': 'cleaning_the_floor',
#   'cleaning_floor/80.mp4': 'cleaning_the_floor',
#   'cleaning_floor/55.mp4': 'cleaning_the_floor',
#   'cleaning_floor/85.mp4': 'cleaning_the_floor',
#   'cleaning_floor/78.mp4': 'cleaning_the_floor',
#   'cleaning_floor/87.mp4': 'cleaning_the_floor',
#   'cleaning_floor/3.mp4': 'cleaning_the_floor',
#   'cleaning_floor/14.mp4': 'cleaning_the_floor',
#   'cleaning_floor/41.mp4': 'cleaning_the_floor',
#   'cleaning_floor/43.mp4': 'cleaning_the_floor',
#   'cleaning_floor/50.mp4': 'cleaning_the_floor',
#   'cleaning_floor/60.mp4': 'cleaning_the_floor',
#   'cleaning_floor/89.mp4': 'cleaning_the_floor',
#   'cleaning_floor/15.mp4': 'cleaning_the_floor',
#   'cleaning_floor/64.mp4': 'cleaning_the_floor',
#   'cleaning_floor/48.mp4': 'cleaning_the_floor',
#   'cleaning_floor/61.mp4': 'cleaning_the_floor',
#   'cleaning_floor/83.mp4': 'cleaning_the_floor',
#   'cleaning_floor/59.mp4': 'cleaning_the_floor',
#   'cleaning_floor/7.mp4': 'cleaning_the_floor',
#   'cleaning_floor/44.mp4': 'cleaning_the_floor',
#   'cleaning_floor/45.mp4': 'cleaning_the_floor',
#   'cleaning_floor/1.mp4': 'cleaning_the_floor',
#   'cleaning_floor/35.mp4': 'cleaning_the_floor',
#   'cleaning_floor/31.mp4': 'cleaning_the_floor',
#   'cleaning_floor/82.mp4': 'cleaning_the_floor',
#   'cleaning_floor/53.mp4': 'cleaning_the_floor',
#   'cleaning_floor/9.mp4': 'cleaning_the_floor',
#   'cleaning_floor/34.mp4': 'cleaning_the_floor',
#   'cleaning_floor/26.mp4': 'cleaning_the_floor',
#   'cleaning_floor/84.mp4': 'cleaning_the_floor',
#   'cleaning_floor/51.mp4': 'cleaning_the_floor',
#   'cleaning_floor/28.mp4': 'cleaning_the_floor',
#   'cleaning_floor/75.mp4': 'cleaning_the_floor',
#   'cleaning_floor/27.mp4': 'cleaning_the_floor',
#   'cleaning_floor/10.mp4': 'cleaning_the_floor',
#   'cleaning_floor/74.mp4': 'cleaning_the_floor',
#   'cleaning_floor/33.mp4': 'cleaning_the_floor',
#   'cleaning_floor/13.mp4': 'cleaning_the_floor',
#   'cleaning_floor/6.mp4': 'cleaning_the_floor',
#   'cleaning_floor/67.mp4': 'cleaning_the_floor',
#   'cleaning_floor/72.mp4': 'cleaning_the_floor',
#   'cleaning_floor/62.mp4': 'cleaning_the_floor',
#   'cleaning_floor/40.mp4': 'cleaning_the_floor',
#   'cleaning_floor/18.mp4': 'cleaning_the_floor',
#   'cleaning_floor/37.mp4': 'cleaning_the_floor',
#   'cleaning_floor/86.mp4': 'cleaning_the_floor',
#   'cleaning_floor/4.mp4': 'cleaning_the_floor',
#   'cleaning_floor/36.mp4': 'cleaning_the_floor',
#   'smoking/38.mp4': 'smoking',
#   'smoking/57.mp4': 'smoking',
#   'smoking/31.mp4': 'smoking',
#   'smoking/34.mp4': 'smoking',
#   'smoking/26.mp4': 'smoking',
#   'smoking/67.mp4': 'smoking',
#   'pushing_cart/32.mp4': 'pushing_a_cart',
#   'pushing_cart/30.mp4': 'pushing_a_cart',
#   'pushing_cart/38.mp4': 'pushing_a_cart',
#   'pushing_cart/46.mp4': 'pushing_a_cart',
#   'pushing_cart/63.mp4': 'pushing_a_cart',
#   'pushing_cart/8.mp4': 'pushing_a_cart',
#   'pushing_cart/5.mp4': 'pushing_a_cart',
#   'pushing_cart/69.mp4': 'pushing_a_cart',
#   'pushing_cart/77.mp4': 'pushing_a_cart',
#   'pushing_cart/2.mp4': 'pushing_a_cart',
#   'pushing_cart/12.mp4': 'pushing_a_cart',
#   'pushing_cart/16.mp4': 'pushing_a_cart',
#   'pushing_cart/79.mp4': 'pushing_a_cart',
#   'pushing_cart/85.mp4': 'pushing_a_cart',
#   'pushing_cart/73.mp4': 'pushing_a_cart',
#   'pushing_cart/78.mp4': 'pushing_a_cart',
#   'pushing_cart/87.mp4': 'pushing_a_cart',
#   'pushing_cart/3.mp4': 'pushing_a_cart',
#   'pushing_cart/41.mp4': 'pushing_a_cart',
#   'pushing_cart/50.mp4': 'pushing_a_cart',
#   'pushing_cart/60.mp4': 'pushing_a_cart',
#   'pushing_cart/89.mp4': 'pushing_a_cart',
#   'pushing_cart/15.mp4': 'pushing_a_cart',
#   'pushing_cart/64.mp4': 'pushing_a_cart',
#   'pushing_cart/48.mp4': 'pushing_a_cart',
#   'pushing_cart/11.mp4': 'pushing_a_cart',
#   'pushing_cart/83.mp4': 'pushing_a_cart',
#   'pushing_cart/68.mp4': 'pushing_a_cart',
#   'pushing_cart/7.mp4': 'pushing_a_cart',
#   'pushing_cart/88.mp4': 'pushing_a_cart',
#   'pushing_cart/45.mp4': 'pushing_a_cart',
#   'pushing_cart/35.mp4': 'pushing_a_cart',
#   'pushing_cart/31.mp4': 'pushing_a_cart',
#   'pushing_cart/24.mp4': 'pushing_a_cart',
#   'pushing_cart/53.mp4': 'pushing_a_cart',
#   'pushing_cart/34.mp4': 'pushing_a_cart',
#   'pushing_cart/84.mp4': 'pushing_a_cart',
#   'pushing_cart/51.mp4': 'pushing_a_cart',
#   'pushing_cart/28.mp4': 'pushing_a_cart',
#   'pushing_cart/56.mp4': 'pushing_a_cart',
#   'pushing_cart/90.mp4': 'pushing_a_cart',
#   'pushing_cart/25.mp4': 'pushing_a_cart',
#   'pushing_cart/27.mp4': 'pushing_a_cart',
#   'pushing_cart/10.mp4': 'pushing_a_cart',
#   'pushing_cart/52.mp4': 'pushing_a_cart',
#   'pushing_cart/74.mp4': 'pushing_a_cart',
#   'pushing_cart/13.mp4': 'pushing_a_cart',
#   'pushing_cart/6.mp4': 'pushing_a_cart',
#   'pushing_cart/70.mp4': 'pushing_a_cart',
#   'pushing_cart/67.mp4': 'pushing_a_cart',
#   'pushing_cart/62.mp4': 'pushing_a_cart',
#   'pushing_cart/37.mp4': 'pushing_a_cart',
#   'pushing_cart/47.mp4': 'pushing_a_cart',
#   'pushing_cart/86.mp4': 'pushing_a_cart',
#   'pushing_cart/4.mp4': 'pushing_a_cart',
#   'pushing_cart/66.mp4': 'pushing_a_cart',
#   'playing_guitar/32.mp4': 'playing_guitar',
#   'playing_guitar/30.mp4': 'playing_guitar',
#   'playing_guitar/29.mp4': 'playing_guitar',
#   'playing_guitar/38.mp4': 'playing_guitar',
#   'playing_guitar/57.mp4': 'playing_guitar',
#   'playing_guitar/63.mp4': 'playing_guitar',
#   'playing_guitar/8.mp4': 'playing_guitar',
#   'playing_guitar/5.mp4': 'playing_guitar',
#   'playing_guitar/69.mp4': 'playing_guitar',
#   'playing_guitar/77.mp4': 'playing_guitar',
#   'playing_guitar/54.mp4': 'playing_guitar',
#   'playing_guitar/65.mp4': 'playing_guitar',
#   'playing_guitar/2.mp4': 'playing_guitar',
#   'playing_guitar/12.mp4': 'playing_guitar',
#   'playing_guitar/42.mp4': 'playing_guitar',
#   'playing_guitar/79.mp4': 'playing_guitar',
#   'playing_guitar/80.mp4': 'playing_guitar',
#   'playing_guitar/55.mp4': 'playing_guitar',
#   'playing_guitar/85.mp4': 'playing_guitar',
#   'playing_guitar/78.mp4': 'playing_guitar',
#   'playing_guitar/3.mp4': 'playing_guitar',
#   'playing_guitar/76.mp4': 'playing_guitar',
#   'playing_guitar/41.mp4': 'playing_guitar',
#   'playing_guitar/50.mp4': 'playing_guitar',
#   'playing_guitar/60.mp4': 'playing_guitar',
#   'playing_guitar/15.mp4': 'playing_guitar',
#   'playing_guitar/48.mp4': 'playing_guitar',
#   'playing_guitar/61.mp4': 'playing_guitar',
#   'playing_guitar/11.mp4': 'playing_guitar',
#   'playing_guitar/83.mp4': 'playing_guitar',
#   'playing_guitar/68.mp4': 'playing_guitar',
#   'playing_guitar/59.mp4': 'playing_guitar',
#   'playing_guitar/7.mp4': 'playing_guitar',
#   'playing_guitar/44.mp4': 'playing_guitar',
#   'playing_guitar/81.mp4': 'playing_guitar',
#   'playing_guitar/45.mp4': 'playing_guitar',
#   'playing_guitar/1.mp4': 'playing_guitar',
#   'playing_guitar/35.mp4': 'playing_guitar',
#   'playing_guitar/82.mp4': 'playing_guitar',
#   'playing_guitar/53.mp4': 'playing_guitar',
#   'playing_guitar/9.mp4': 'playing_guitar',
#   'playing_guitar/84.mp4': 'playing_guitar',
#   'playing_guitar/51.mp4': 'playing_guitar',
#   'playing_guitar/28.mp4': 'playing_guitar',
#   'playing_guitar/56.mp4': 'playing_guitar',
#   'playing_guitar/27.mp4': 'playing_guitar',
#   'playing_guitar/52.mp4': 'playing_guitar',
#   'playing_guitar/74.mp4': 'playing_guitar',
#   'playing_guitar/33.mp4': 'playing_guitar',
#   'playing_guitar/13.mp4': 'playing_guitar',
#   'playing_guitar/6.mp4': 'playing_guitar',
#   'playing_guitar/70.mp4': 'playing_guitar',
#   'playing_guitar/67.mp4': 'playing_guitar',
#   'playing_guitar/72.mp4': 'playing_guitar',
#   'playing_guitar/49.mp4': 'playing_guitar',
#   'playing_guitar/62.mp4': 'playing_guitar',
#   'playing_guitar/40.mp4': 'playing_guitar',
#   'playing_guitar/37.mp4': 'playing_guitar',
#   'playing_guitar/47.mp4': 'playing_guitar',
#   'playing_guitar/86.mp4': 'playing_guitar',
#   'playing_guitar/4.mp4': 'playing_guitar',
#   'playing_guitar/66.mp4': 'playing_guitar',
#   'playing_guitar/36.mp4': 'playing_guitar'},
#  'in_top_5': {'drinking/32.mp4': ['washing_dishes',
#    'blowing_bubbles',
#    'waving_hands',
#    'drinking',
#    'applauding'],
#   'drinking/57.mp4': ['watching_TV',
#    'drinking',
#    'pouring_liquid',
#    'brushing_teeth',
#    'writing_on_a_board'],
#   'drinking/46.mp4': ['drinking',
#    'blowing_bubbles',
#    'brushing_teeth',
#    'reading',
#    'writing_on_a_book'],
#   'drinking/63.mp4': ['waving_hands',
#    'pushing_a_cart',
#    'blowing_bubbles',
#    'drinking',
#    'brushing_teeth'],
#   'drinking/5.mp4': ['writing_on_a_board',
#    'playing_guitar',
#    'running',
#    'drinking',
#    'applauding'],
#   'drinking/69.mp4': ['pouring_liquid',
#    'drinking',
#    'waving_hands',
#    'writing_on_a_book',
#    'brushing_teeth'],
#   'drinking/54.mp4': ['texting_message',
#    'brushing_teeth',
#    'drinking',
#    'pouring_liquid',
#    'applauding'],
#   'drinking/16.mp4': ['writing_on_a_book',
#    'drinking',
#    'reading',
#    'applauding',
#    'pouring_liquid'],
#   'drinking/41.mp4': ['reading',
#    'fixing_a_car',
#    'drinking',
#    'looking_through_a_microscope',
#    'pouring_liquid'],
#   'drinking/43.mp4': ['drinking',
#    'blowing_bubbles',
#    'brushing_teeth',
#    'writing_on_a_book',
#    'applauding'],
#   'drinking/50.mp4': ['applauding',
#    'blowing_bubbles',
#    'waving_hands',
#    'drinking',
#    'brushing_teeth'],
#   'drinking/61.mp4': ['blowing_bubbles',
#    'waving_hands',
#    'drinking',
#    'applauding',
#    'writing_on_a_board'],
#   'drinking/20.mp4': ['smoking',
#    'brushing_teeth',
#    'looking_through_a_microscope',
#    'drinking',
#    'phoning'],
#   'drinking/81.mp4': ['running',
#    'drinking',
#    'writing_on_a_board',
#    'taking_photos',
#    'looking_through_a_telescope'],
#   'drinking/82.mp4': ['smoking',
#    'drinking',
#    'texting_message',
#    'writing_on_a_board',
#    'applauding'],
#   'drinking/53.mp4': ['using_a_computer',
#    'writing_on_a_board',
#    'drinking',
#    'pouring_liquid',
#    'reading'],
#   'drinking/34.mp4': ['drinking',
#    'taking_photos',
#    'writing_on_a_board',
#    'applauding',
#    'pushing_a_cart'],
#   'drinking/56.mp4': ['writing_on_a_board',
#    'blowing_bubbles',
#    'applauding',
#    'drinking',
#    'brushing_teeth'],
#   'drinking/52.mp4': ['taking_photos',
#    'writing_on_a_board',
#    'watching_TV',
#    'drinking',
#    'applauding'],
#   'drinking/33.mp4': ['drinking',
#    'pouring_liquid',
#    'looking_through_a_telescope',
#    'watching_TV',
#    'writing_on_a_board'],
#   'drinking/72.mp4': ['brushing_teeth',
#    'drinking',
#    'watching_TV',
#    'looking_through_a_telescope',
#    'writing_on_a_board'],
#   'drinking/47.mp4': ['brushing_teeth',
#    'cutting_vegetables',
#    'pouring_liquid',
#    'drinking',
#    'washing_dishes'],
#   'drinking/4.mp4': ['pouring_liquid',
#    'applauding',
#    'drinking',
#    'running',
#    'taking_photos'],
#   'drinking/66.mp4': ['writing_on_a_book',
#    'pouring_liquid',
#    'reading',
#    'drinking',
#    'applauding'],
#   'drinking/36.mp4': ['writing_on_a_book',
#    'smoking',
#    'drinking',
#    'texting_message',
#    'pouring_liquid'],
#   'texting/30.mp4': ['applauding',
#    'reading',
#    'writing_on_a_book',
#    'texting_message',
#    'waving_hands'],
#   'texting/57.mp4': ['phoning',
#    'applauding',
#    'watching_TV',
#    'texting_message',
#    'writing_on_a_board'],
#   'texting/69.mp4': ['texting_message',
#    'writing_on_a_book',
#    'applauding',
#    'writing_on_a_board',
#    'using_a_computer'],
#   'texting/65.mp4': ['taking_photos',
#    'texting_message',
#    'writing_on_a_board',
#    'running',
#    'waving_hands'],
#   'texting/39.mp4': ['pushing_a_cart',
#    'phoning',
#    'looking_through_a_microscope',
#    'texting_message',
#    'fixing_a_car'],
#   'texting/42.mp4': ['reading',
#    'waving_hands',
#    'writing_on_a_board',
#    'texting_message',
#    'watching_TV'],
#   'texting/79.mp4': ['using_a_computer',
#    'drinking',
#    'writing_on_a_board',
#    'texting_message',
#    'watching_TV'],
#   'texting/3.mp4': ['pushing_a_cart',
#    'phoning',
#    'running',
#    'texting_message',
#    'taking_photos'],
#   'texting/14.mp4': ['taking_photos',
#    'phoning',
#    'watching_TV',
#    'texting_message',
#    'writing_on_a_board'],
#   'texting/76.mp4': ['texting_message',
#    'looking_through_a_telescope',
#    'fixing_a_car',
#    'waving_hands',
#    'writing_on_a_book'],
#   'texting/60.mp4': ['reading',
#    'texting_message',
#    'taking_photos',
#    'phoning',
#    'writing_on_a_book'],
#   'texting/64.mp4': ['using_a_computer',
#    'reading',
#    'texting_message',
#    'brushing_teeth',
#    'writing_on_a_board'],
#   'texting/61.mp4': ['running',
#    'reading',
#    'taking_photos',
#    'texting_message',
#    'phoning'],
#   'texting/7.mp4': ['drinking',
#    'writing_on_a_book',
#    'reading',
#    'texting_message',
#    'pouring_liquid'],
#   'texting/81.mp4': ['smoking',
#    'writing_on_a_board',
#    'texting_message',
#    'fixing_a_car',
#    'waving_hands'],
#   'texting/82.mp4': ['writing_on_a_board',
#    'looking_through_a_microscope',
#    'texting_message',
#    'applauding',
#    'reading'],
#   'texting/53.mp4': ['writing_on_a_book',
#    'taking_photos',
#    'applauding',
#    'texting_message',
#    'phoning'],
#   'texting/9.mp4': ['reading',
#    'looking_through_a_microscope',
#    'texting_message',
#    'watching_TV',
#    'writing_on_a_board'],
#   'texting/56.mp4': ['applauding',
#    'brushing_teeth',
#    'waving_hands',
#    'texting_message',
#    'smoking'],
#   'texting/19.mp4': ['looking_through_a_telescope',
#    'taking_photos',
#    'phoning',
#    'texting_message',
#    'writing_on_a_board'],
#   'texting/33.mp4': ['reading',
#    'smoking',
#    'waving_hands',
#    'texting_message',
#    'watching_TV'],
#   'texting/6.mp4': ['smoking',
#    'watching_TV',
#    'taking_photos',
#    'texting_message',
#    'phoning'],
#   'texting/62.mp4': ['watching_TV',
#    'using_a_computer',
#    'taking_photos',
#    'texting_message',
#    'phoning'],
#   'texting/40.mp4': ['writing_on_a_book',
#    'smoking',
#    'phoning',
#    'texting_message',
#    'brushing_teeth'],
#   'texting/47.mp4': ['writing_on_a_book',
#    'fixing_a_car',
#    'looking_through_a_telescope',
#    'texting_message',
#    'waving_hands'],
#   'texting/36.mp4': ['phoning',
#    'waving_hands',
#    'writing_on_a_book',
#    'texting_message',
#    'running'],
#   'playing_violin/30.mp4': ['taking_photos',
#    'shooting_an_arrow',
#    'playing_violin',
#    'cleaning_the_floor',
#    'applauding'],
#   'playing_violin/38.mp4': ['drinking',
#    'looking_through_a_telescope',
#    'applauding',
#    'playing_violin',
#    'playing_guitar'],
#   'playing_violin/2.mp4': ['playing_violin',
#    'taking_photos',
#    'applauding',
#    'playing_guitar',
#    'blowing_bubbles'],
#   'playing_violin/79.mp4': ['writing_on_a_board',
#    'looking_through_a_telescope',
#    'playing_violin',
#    'applauding',
#    'playing_guitar'],
#   'playing_violin/14.mp4': ['drinking',
#    'applauding',
#    'playing_violin',
#    'pouring_liquid',
#    'writing_on_a_book'],
#   'playing_violin/34.mp4': ['playing_guitar',
#    'waving_hands',
#    'playing_violin',
#    'taking_photos',
#    'writing_on_a_board'],
#   'playing_violin/75.mp4': ['reading',
#    'writing_on_a_book',
#    'playing_violin',
#    'playing_guitar',
#    'applauding'],
#   'playing_violin/21.mp4': ['applauding',
#    'waving_hands',
#    'fishing',
#    'playing_violin',
#    'playing_guitar'],
#   'playing_violin/93.mp4': ['playing_violin',
#    'writing_on_a_board',
#    'applauding',
#    'playing_guitar',
#    'taking_photos'],
#   'playing_violin/37.mp4': ['taking_photos',
#    'blowing_bubbles',
#    'writing_on_a_board',
#    'playing_violin',
#    'applauding'],
#   'playing_violin/71.mp4': ['looking_through_a_microscope',
#    'looking_through_a_telescope',
#    'watching_TV',
#    'playing_violin',
#    'writing_on_a_board'],
#   'washing_dishes/38.mp4': ['cleaning_the_floor',
#    'washing_dishes',
#    'cutting_vegetables',
#    'writing_on_a_board',
#    'watching_TV'],
#   'washing_dishes/46.mp4': ['writing_on_a_book',
#    'blowing_bubbles',
#    'pouring_liquid',
#    'washing_dishes',
#    'looking_through_a_microscope'],
#   'washing_dishes/69.mp4': ['pouring_liquid',
#    'watching_TV',
#    'washing_dishes',
#    'looking_through_a_microscope',
#    'writing_on_a_book'],
#   'washing_dishes/77.mp4': ['drinking',
#    'washing_dishes',
#    'pouring_liquid',
#    'applauding',
#    'looking_through_a_microscope'],
#   'washing_dishes/65.mp4': ['pouring_liquid',
#    'brushing_teeth',
#    'washing_dishes',
#    'looking_through_a_microscope',
#    'writing_on_a_board'],
#   'washing_dishes/12.mp4': ['looking_through_a_microscope',
#    'blowing_bubbles',
#    'cooking',
#    'washing_dishes',
#    'pouring_liquid'],
#   'washing_dishes/80.mp4': ['using_a_computer',
#    'looking_through_a_microscope',
#    'writing_on_a_board',
#    'washing_dishes',
#    'cleaning_the_floor'],
#   'washing_dishes/73.mp4': ['looking_through_a_microscope',
#    'cutting_vegetables',
#    'washing_dishes',
#    'cooking',
#    'pouring_liquid'],
#   'washing_dishes/87.mp4': ['washing_dishes',
#    'reading',
#    'cutting_vegetables',
#    'writing_on_a_book',
#    'looking_through_a_microscope'],
#   'washing_dishes/3.mp4': ['drinking',
#    'pouring_liquid',
#    'cooking',
#    'washing_dishes',
#    'cutting_vegetables'],
#   'washing_dishes/14.mp4': ['pouring_liquid',
#    'writing_on_a_book',
#    'washing_dishes',
#    'cutting_vegetables',
#    'cooking'],
#   'washing_dishes/76.mp4': ['pouring_liquid',
#    'looking_through_a_microscope',
#    'cutting_vegetables',
#    'washing_dishes',
#    'cooking'],
#   'washing_dishes/83.mp4': ['washing_dishes',
#    'writing_on_a_book',
#    'brushing_teeth',
#    'applauding',
#    'looking_through_a_microscope'],
#   'washing_dishes/68.mp4': ['washing_dishes',
#    'pouring_liquid',
#    'cutting_vegetables',
#    'cooking',
#    'looking_through_a_microscope'],
#   'washing_dishes/7.mp4': ['cooking',
#    'writing_on_a_board',
#    'washing_dishes',
#    'watching_TV',
#    'looking_through_a_microscope'],
#   'washing_dishes/35.mp4': ['pouring_liquid',
#    'writing_on_a_book',
#    'cooking',
#    'washing_dishes',
#    'cutting_vegetables'],
#   'washing_dishes/82.mp4': ['writing_on_a_book',
#    'watching_TV',
#    'pouring_liquid',
#    'washing_dishes',
#    'cutting_vegetables'],
#   'washing_dishes/34.mp4': ['cutting_vegetables',
#    'cooking',
#    'pouring_liquid',
#    'washing_dishes',
#    'drinking'],
#   'washing_dishes/51.mp4': ['cutting_vegetables',
#    'applauding',
#    'washing_dishes',
#    'pouring_liquid',
#    'cooking'],
#   'washing_dishes/21.mp4': ['cooking',
#    'looking_through_a_microscope',
#    'cutting_vegetables',
#    'washing_dishes',
#    'cleaning_the_floor'],
#   'washing_dishes/52.mp4': ['watching_TV',
#    'cooking',
#    'washing_dishes',
#    'looking_through_a_microscope',
#    'writing_on_a_board'],
#   'washing_dishes/33.mp4': ['running',
#    'cooking',
#    'washing_dishes',
#    'cutting_vegetables',
#    'cleaning_the_floor'],
#   'washing_dishes/23.mp4': ['pouring_liquid',
#    'brushing_teeth',
#    'washing_dishes',
#    'looking_through_a_microscope',
#    'writing_on_a_board'],
#   'walking_the_dog/38.mp4': ['cutting_trees',
#    'looking_through_a_telescope',
#    'blowing_bubbles',
#    'walking_the_dog',
#    'fishing'],
#   'walking_the_dog/63.mp4': ['riding_a_bike',
#    'fishing',
#    'pushing_a_cart',
#    'walking_the_dog',
#    'running'],
#   'walking_the_dog/8.mp4': ['jumping',
#    'looking_through_a_telescope',
#    'walking_the_dog',
#    'running',
#    'fishing'],
#   'walking_the_dog/69.mp4': ['cleaning_the_floor',
#    'walking_the_dog',
#    'running',
#    'watching_TV',
#    'writing_on_a_board'],
#   'walking_the_dog/65.mp4': ['taking_photos',
#    'throwing_frisby',
#    'cutting_trees',
#    'walking_the_dog',
#    'gardening'],
#   'walking_the_dog/55.mp4': ['blowing_bubbles',
#    'jumping',
#    'walking_the_dog',
#    'waving_hands',
#    'gardening'],
#   'walking_the_dog/85.mp4': ['texting_message',
#    'walking_the_dog',
#    'writing_on_a_book',
#    'gardening',
#    'waving_hands'],
#   'walking_the_dog/73.mp4': ['running',
#    'riding_a_horse',
#    'throwing_frisby',
#    'walking_the_dog',
#    'gardening'],
#   'walking_the_dog/87.mp4': ['pushing_a_cart',
#    'riding_a_bike',
#    'feeding_a_horse',
#    'walking_the_dog',
#    'running'],
#   'walking_the_dog/3.mp4': ['waving_hands',
#    'phoning',
#    'walking_the_dog',
#    'taking_photos',
#    'running'],
#   'walking_the_dog/92.mp4': ['throwing_frisby',
#    'taking_photos',
#    'applauding',
#    'walking_the_dog',
#    'running'],
#   'walking_the_dog/89.mp4': ['gardening',
#    'jumping',
#    'running',
#    'walking_the_dog',
#    'throwing_frisby'],
#   'walking_the_dog/15.mp4': ['blowing_bubbles',
#    'throwing_frisby',
#    'running',
#    'walking_the_dog',
#    'jumping'],
#   'walking_the_dog/48.mp4': ['cutting_vegetables',
#    'running',
#    'walking_the_dog',
#    'throwing_frisby',
#    'looking_through_a_telescope'],
#   'walking_the_dog/11.mp4': ['jumping',
#    'taking_photos',
#    'walking_the_dog',
#    'writing_on_a_board',
#    'running'],
#   'walking_the_dog/59.mp4': ['looking_through_a_telescope',
#    'shooting_an_arrow',
#    'walking_the_dog',
#    'throwing_frisby',
#    'running'],
#   'walking_the_dog/44.mp4': ['smoking',
#    'looking_through_a_telescope',
#    'walking_the_dog',
#    'waving_hands',
#    'gardening'],
#   'walking_the_dog/1.mp4': ['running',
#    'shooting_an_arrow',
#    'feeding_a_horse',
#    'walking_the_dog',
#    'cutting_trees'],
#   'walking_the_dog/35.mp4': ['pushing_a_cart',
#    'walking_the_dog',
#    'riding_a_bike',
#    'fishing',
#    'running'],
#   'walking_the_dog/51.mp4': ['fishing',
#    'jumping',
#    'pushing_a_cart',
#    'walking_the_dog',
#    'running'],
#   'walking_the_dog/28.mp4': ['riding_a_bike',
#    'using_a_computer',
#    'taking_photos',
#    'walking_the_dog',
#    'running'],
#   'walking_the_dog/27.mp4': ['running',
#    'walking_the_dog',
#    'taking_photos',
#    'gardening',
#    'writing_on_a_board'],
#   'walking_the_dog/13.mp4': ['looking_through_a_telescope',
#    'running',
#    'cutting_trees',
#    'walking_the_dog',
#    'writing_on_a_board'],
#   'walking_the_dog/91.mp4': ['waving_hands',
#    'jumping',
#    'walking_the_dog',
#    'running',
#    'gardening'],
#   'walking_the_dog/72.mp4': ['applauding',
#    'walking_the_dog',
#    'riding_a_bike',
#    'waving_hands',
#    'running'],
#   'walking_the_dog/49.mp4': ['feeding_a_horse',
#    'cutting_trees',
#    'writing_on_a_board',
#    'walking_the_dog',
#    'watching_TV'],
#   'walking_the_dog/40.mp4': ['throwing_frisby',
#    'shooting_an_arrow',
#    'walking_the_dog',
#    'running',
#    'jumping'],
#   'walking_the_dog/93.mp4': ['taking_photos',
#    'riding_a_bike',
#    'walking_the_dog',
#    'fishing',
#    'running'],
#   'walking_the_dog/47.mp4': ['taking_photos',
#    'looking_through_a_telescope',
#    'walking_the_dog',
#    'fishing',
#    'running'],
#   'reading_book/32.mp4': ['watching_TV',
#    'looking_through_a_microscope',
#    'using_a_computer',
#    'reading',
#    'writing_on_a_book'],
#   'reading_book/30.mp4': ['looking_through_a_microscope',
#    'cutting_vegetables',
#    'drinking',
#    'reading',
#    'writing_on_a_book'],
#   'reading_book/29.mp4': ['writing_on_a_book',
#    'cutting_vegetables',
#    'applauding',
#    'reading',
#    'writing_on_a_board'],
#   'reading_book/38.mp4': ['using_a_computer',
#    'looking_through_a_microscope',
#    'writing_on_a_board',
#    'reading',
#    'writing_on_a_book'],
#   'reading_book/46.mp4': ['pouring_liquid',
#    'using_a_computer',
#    'looking_through_a_microscope',
#    'reading',
#    'writing_on_a_book'],
#   'reading_book/54.mp4': ['looking_through_a_microscope',
#    'brushing_teeth',
#    'reading',
#    'writing_on_a_book',
#    'writing_on_a_board'],
#   'reading_book/65.mp4': ['pouring_liquid',
#    'looking_through_a_microscope',
#    'reading',
#    'writing_on_a_book',
#    'cutting_vegetables'],
#   'reading_book/39.mp4': ['pouring_liquid',
#    'using_a_computer',
#    'cutting_vegetables',
#    'reading',
#    'writing_on_a_book'],
#   'reading_book/85.mp4': ['waving_hands',
#    'drinking',
#    'writing_on_a_book',
#    'reading',
#    'writing_on_a_board'],
#   'reading_book/73.mp4': ['using_a_computer',
#    'texting_message',
#    'reading',
#    'cutting_vegetables',
#    'writing_on_a_book'],
#   'reading_book/87.mp4': ['cleaning_the_floor',
#    'using_a_computer',
#    'watching_TV',
#    'reading',
#    'writing_on_a_book'],
#   'reading_book/14.mp4': ['cutting_vegetables',
#    'washing_dishes',
#    'using_a_computer',
#    'reading',
#    'writing_on_a_book'],
#   'reading_book/41.mp4': ['pouring_liquid',
#    'writing_on_a_book',
#    'cutting_vegetables',
#    'reading',
#    'writing_on_a_board'],
#   'reading_book/60.mp4': ['pouring_liquid',
#    'looking_through_a_microscope',
#    'reading',
#    'applauding',
#    'writing_on_a_book'],
#   'reading_book/61.mp4': ['washing_dishes',
#    'cutting_vegetables',
#    'using_a_computer',
#    'reading',
#    'writing_on_a_book'],
#   'reading_book/59.mp4': ['watching_TV',
#    'drinking',
#    'writing_on_a_book',
#    'reading',
# ...
#    'applauding'],
#   'drinking_beer/44.mp4': ['pouring_liquid',
#    'cutting_vegetables',
#    'drinking',
#    'applauding',
#    'running'],
#   'drinking_beer/81.mp4': ['walking_the_dog',
#    'drinking',
#    'pouring_liquid',
#    'playing_guitar',
#    'applauding'],
#   'drinking_beer/88.mp4': ['washing_dishes',
#    'pouring_liquid',
#    'looking_through_a_telescope',
#    'drinking',
#    'writing_on_a_board'],
#   'drinking_beer/74.mp4': ['writing_on_a_book',
#    'writing_on_a_board',
#    'drinking',
#    'taking_photos',
#    'applauding'],
#   'drinking_beer/6.mp4': ['applauding',
#    'taking_photos',
#    'waving_hands',
#    'drinking',
#    'writing_on_a_board'],
#   'drinking_beer/70.mp4': ['pouring_liquid',
#    'taking_photos',
#    'writing_on_a_board',
#    'drinking',
#    'applauding'],
#   'drinking_beer/67.mp4': ['drinking',
#    'texting_message',
#    'taking_photos',
#    'applauding',
#    'writing_on_a_board'],
#   'drinking_beer/72.mp4': ['writing_on_a_book',
#    'blowing_bubbles',
#    'drinking',
#    'cooking',
#    'pouring_liquid'],
#   'drinking_beer/62.mp4': ['drinking',
#    'waving_hands',
#    'looking_through_a_telescope',
#    'running',
#    'walking_the_dog'],
#   'drinking_beer/47.mp4': ['waving_hands',
#    'applauding',
#    'drinking',
#    'brushing_teeth',
#    'writing_on_a_board'],
#   'drinking_beer/86.mp4': ['looking_through_a_microscope',
#    'cutting_vegetables',
#    'fixing_a_bike',
#    'drinking',
#    'pouring_liquid'],
#   'drinking_beer/4.mp4': ['waving_hands',
#    'applauding',
#    'looking_through_a_microscope',
#    'drinking',
#    'reading'],
#   'drinking_beer/66.mp4': ['writing_on_a_book',
#    'cooking',
#    'pouring_liquid',
#    'drinking',
#    'blowing_bubbles'],
#   'drinking_beer/71.mp4': ['drinking',
#    'waving_hands',
#    'cutting_vegetables',
#    'washing_dishes',
#    'cooking'],
#   'cleaning_floor/17.mp4': ['playing_guitar',
#    'running',
#    'taking_photos',
#    'cleaning_the_floor',
#    'pushing_a_cart'],
#   'cleaning_floor/39.mp4': ['watching_TV',
#    'looking_through_a_microscope',
#    'taking_photos',
#    'cleaning_the_floor',
#    'writing_on_a_board'],
#   'cleaning_floor/76.mp4': ['smoking',
#    'cutting_vegetables',
#    'brushing_teeth',
#    'cleaning_the_floor',
#    'washing_dishes'],
#   'cleaning_floor/11.mp4': ['looking_through_a_microscope',
#    'cleaning_the_floor',
#    'drinking',
#    'writing_on_a_board',
#    'looking_through_a_telescope'],
#   'cleaning_floor/68.mp4': ['cutting_vegetables',
#    'pouring_liquid',
#    'cleaning_the_floor',
#    'washing_dishes',
#    'drinking'],
#   'cleaning_floor/88.mp4': ['walking_the_dog',
#    'fixing_a_bike',
#    'reading',
#    'cleaning_the_floor',
#    'looking_through_a_microscope'],
#   'cleaning_floor/49.mp4': ['reading',
#    'jumping',
#    'cutting_vegetables',
#    'cleaning_the_floor',
#    'pushing_a_cart'],
#   'cleaning_floor/47.mp4': ['running',
#    'waving_hands',
#    'fishing',
#    'cleaning_the_floor',
#    'pushing_a_cart'],
#   'smoking/30.mp4': ['drinking',
#    'texting_message',
#    'applauding',
#    'smoking',
#    'writing_on_a_board'],
#   'smoking/29.mp4': ['smoking',
#    'applauding',
#    'taking_photos',
#    'drinking',
#    'brushing_teeth'],
#   'smoking/46.mp4': ['texting_message',
#    'brushing_teeth',
#    'writing_on_a_board',
#    'smoking',
#    'taking_photos'],
#   'smoking/63.mp4': ['brushing_teeth',
#    'smoking',
#    'waving_hands',
#    'applauding',
#    'watching_TV'],
#   'smoking/69.mp4': ['taking_photos',
#    'smoking',
#    'writing_on_a_book',
#    'waving_hands',
#    'texting_message'],
#   'smoking/12.mp4': ['waving_hands',
#    'brushing_teeth',
#    'writing_on_a_book',
#    'smoking',
#    'texting_message'],
#   'smoking/42.mp4': ['cooking',
#    'smoking',
#    'waving_hands',
#    'applauding',
#    'blowing_bubbles'],
#   'smoking/58.mp4': ['blowing_bubbles',
#    'drinking',
#    'texting_message',
#    'smoking',
#    'brushing_teeth'],
#   'smoking/73.mp4': ['smoking',
#    'looking_through_a_microscope',
#    'cutting_vegetables',
#    'reading',
#    'texting_message'],
#   'smoking/60.mp4': ['brushing_teeth',
#    'texting_message',
#    'smoking',
#    'applauding',
#    'writing_on_a_board'],
#   'smoking/15.mp4': ['walking_the_dog',
#    'phoning',
#    'waving_hands',
#    'smoking',
#    'running'],
#   'smoking/35.mp4': ['phoning',
#    'looking_through_a_microscope',
#    'pouring_liquid',
#    'smoking',
#    'applauding'],
#   'smoking/24.mp4': ['waving_hands',
#    'drinking',
#    'smoking',
#    'applauding',
#    'brushing_teeth'],
#   'smoking/9.mp4': ['writing_on_a_board',
#    'smoking',
#    'drinking',
#    'brushing_teeth',
#    'texting_message'],
#   'smoking/51.mp4': ['writing_on_a_book',
#    'drinking',
#    'applauding',
#    'smoking',
#    'brushing_teeth'],
#   'smoking/56.mp4': ['texting_message',
#    'brushing_teeth',
#    'cutting_trees',
#    'smoking',
#    'drinking'],
#   'smoking/25.mp4': ['texting_message',
#    'waving_hands',
#    'smoking',
#    'brushing_teeth',
#    'applauding'],
#   'smoking/75.mp4': ['texting_message',
#    'waving_hands',
#    'smoking',
#    'gardening',
#    'writing_on_a_board'],
#   'smoking/33.mp4': ['looking_through_a_microscope',
#    'writing_on_a_board',
#    'brushing_teeth',
#    'smoking',
#    'applauding'],
#   'smoking/23.mp4': ['writing_on_a_book',
#    'brushing_teeth',
#    'texting_message',
#    'smoking',
#    'writing_on_a_board'],
#   'smoking/6.mp4': ['applauding',
#    'smoking',
#    'pouring_liquid',
#    'waving_hands',
#    'drinking'],
#   'smoking/47.mp4': ['brushing_teeth',
#    'writing_on_a_book',
#    'waving_hands',
#    'smoking',
#    'applauding'],
#   'smoking/36.mp4': ['drinking',
#    'texting_message',
#    'writing_on_a_book',
#    'smoking',
#    'brushing_teeth'],
#   'pushing_cart/17.mp4': ['climbing',
#    'writing_on_a_board',
#    'cleaning_the_floor',
#    'pushing_a_cart',
#    'waving_hands'],
#   'pushing_cart/29.mp4': ['riding_a_bike',
#    'writing_on_a_board',
#    'cleaning_the_floor',
#    'pushing_a_cart',
#    'watching_TV'],
#   'pushing_cart/57.mp4': ['waving_hands',
#    'jumping',
#    'pushing_a_cart',
#    'brushing_teeth',
#    'cleaning_the_floor'],
#   'pushing_cart/54.mp4': ['pushing_a_cart',
#    'jumping',
#    'running',
#    'writing_on_a_board',
#    'cleaning_the_floor'],
#   'pushing_cart/65.mp4': ['gardening',
#    'blowing_bubbles',
#    'washing_dishes',
#    'pushing_a_cart',
#    'waving_hands'],
#   'pushing_cart/42.mp4': ['taking_photos',
#    'pushing_a_cart',
#    'waving_hands',
#    'running',
#    'cleaning_the_floor'],
#   'pushing_cart/14.mp4': ['brushing_teeth',
#    'climbing',
#    'waving_hands',
#    'pushing_a_cart',
#    'cleaning_the_floor'],
#   'pushing_cart/43.mp4': ['cutting_vegetables',
#    'watching_TV',
#    'riding_a_bike',
#    'pushing_a_cart',
#    'cleaning_the_floor'],
#   'pushing_cart/61.mp4': ['cooking',
#    'pushing_a_cart',
#    'riding_a_bike',
#    'blowing_bubbles',
#    'running'],
#   'pushing_cart/59.mp4': ['running',
#    'fishing',
#    'looking_through_a_telescope',
#    'pushing_a_cart',
#    'riding_a_bike'],
#   'pushing_cart/81.mp4': ['watching_TV',
#    'cutting_vegetables',
#    'waving_hands',
#    'pushing_a_cart',
#    'cleaning_the_floor'],
#   'pushing_cart/1.mp4': ['watching_TV',
#    'reading',
#    'using_a_computer',
#    'pushing_a_cart',
#    'cleaning_the_floor'],
#   'pushing_cart/82.mp4': ['running',
#    'smoking',
#    'taking_photos',
#    'pushing_a_cart',
#    'cleaning_the_floor'],
#   'pushing_cart/33.mp4': ['waving_hands',
#    'watching_TV',
#    'jumping',
#    'pushing_a_cart',
#    'cleaning_the_floor'],
#   'pushing_cart/91.mp4': ['writing_on_a_board',
#    'taking_photos',
#    'watching_TV',
#    'pushing_a_cart',
#    'applauding'],
#   'pushing_cart/72.mp4': ['pouring_liquid',
#    'writing_on_a_board',
#    'watching_TV',
#    'pushing_a_cart',
#    'cleaning_the_floor'],
#   'pushing_cart/71.mp4': ['washing_dishes',
#    'riding_a_bike',
#    'pushing_a_cart',
#    'brushing_teeth',
#    'cleaning_the_floor'],
#   'pushing_cart/36.mp4': ['writing_on_a_board',
#    'cleaning_the_floor',
#    'climbing',
#    'pushing_a_cart',
#    'waving_hands'],
#   'playing_guitar/73.mp4': ['phoning',
#    'playing_guitar',
#    'walking_the_dog',
#    'writing_on_a_board',
#    'applauding'],
#   'playing_guitar/34.mp4': ['cutting_trees',
#    'gardening',
#    'blowing_bubbles',
#    'playing_guitar',
#    'writing_on_a_book'],
#   'playing_guitar/10.mp4': ['looking_through_a_microscope',
#    'applauding',
#    'waving_hands',
#    'playing_guitar',
#    'writing_on_a_board']},
#  'incorrect': {'drinking/17.mp4': 'writing_on_a_board',
#   'drinking/30.mp4': 'watching_TV',
#   'drinking/8.mp4': 'taking_photos',
#   'drinking/42.mp4': 'cutting_trees',
#   'drinking/58.mp4': 'looking_through_a_microscope',
#   'drinking/80.mp4': 'pouring_liquid',
#   'drinking/85.mp4': 'throwing_frisby',
#   'drinking/87.mp4': 'taking_photos',
#   'drinking/3.mp4': 'applauding',
#   'drinking/14.mp4': 'writing_on_a_board',
#   'drinking/48.mp4': 'applauding',
#   'drinking/68.mp4': 'watching_TV',
#   'drinking/7.mp4': 'writing_on_a_board',
#   'drinking/88.mp4': 'applauding',
#   'drinking/1.mp4': 'pushing_a_cart',
#   'drinking/35.mp4': 'writing_on_a_board',
#   'drinking/19.mp4': 'running',
#   'drinking/27.mp4': 'waving_hands',
#   'drinking/70.mp4': 'pouring_liquid',
#   'drinking/67.mp4': 'washing_dishes',
#   'drinking/49.mp4': 'writing_on_a_book',
#   'drinking/40.mp4': 'reading',
#   'drinking/18.mp4': 'waving_hands',
#   'drinking/37.mp4': 'looking_through_a_microscope',
#   'drinking/71.mp4': 'looking_through_a_telescope',
#   'texting/32.mp4': 'writing_on_a_board',
#   'texting/29.mp4': 'running',
#   'texting/5.mp4': 'writing_on_a_board',
#   'texting/54.mp4': 'waving_hands',
#   'texting/2.mp4': 'cleaning_the_floor',
#   'texting/12.mp4': 'running',
#   'texting/80.mp4': 'running',
#   'texting/73.mp4': 'writing_on_a_board',
#   'texting/87.mp4': 'watching_TV',
#   'texting/43.mp4': 'taking_photos',
#   'texting/50.mp4': 'writing_on_a_board',
#   'texting/59.mp4': 'taking_photos',
#   'texting/44.mp4': 'cutting_vegetables',
#   'texting/31.mp4': 'applauding',
#   'texting/90.mp4': 'writing_on_a_board',
#   'texting/10.mp4': 'using_a_computer',
#   'texting/70.mp4': 'waving_hands',
#   'texting/72.mp4': 'writing_on_a_board',
#   'texting/4.mp4': 'waving_hands',
#   'playing_violin/29.mp4': 'writing_on_a_board',
#   'playing_violin/85.mp4': 'applauding',
#   'playing_violin/23.mp4': 'taking_photos',
#   'playing_violin/70.mp4': 'writing_on_a_board',
#   'washing_dishes/17.mp4': 'taking_photos',
#   'washing_dishes/54.mp4': 'texting_message',
#   'washing_dishes/2.mp4': 'looking_through_a_microscope',
#   'washing_dishes/50.mp4': 'looking_through_a_telescope',
#   'washing_dishes/84.mp4': 'applauding',
#   'washing_dishes/56.mp4': 'cutting_trees',
#   'washing_dishes/10.mp4': 'pushing_a_cart',
#   'washing_dishes/72.mp4': 'looking_through_a_microscope',
#   'washing_dishes/62.mp4': 'drinking',
#   'washing_dishes/86.mp4': 'cleaning_the_floor',
#   'washing_dishes/4.mp4': 'watching_TV',
#   'washing_dishes/66.mp4': 'cleaning_the_floor',
#   'walking_the_dog/17.mp4': 'jumping',
#   'walking_the_dog/57.mp4': 'running',
#   'walking_the_dog/12.mp4': 'cleaning_the_floor',
#   'walking_the_dog/79.mp4': 'climbing',
#   'walking_the_dog/80.mp4': 'looking_through_a_telescope',
#   'walking_the_dog/78.mp4': 'running',
#   'walking_the_dog/14.mp4': 'fishing',
#   'walking_the_dog/76.mp4': 'running',
#   'walking_the_dog/60.mp4': 'running',
#   'walking_the_dog/61.mp4': 'gardening',
#   'walking_the_dog/20.mp4': 'cleaning_the_floor',
#   'walking_the_dog/31.mp4': 'applauding',
#   'walking_the_dog/9.mp4': 'gardening',
#   'walking_the_dog/84.mp4': 'running',
#   'walking_the_dog/90.mp4': 'cleaning_the_floor',
#   'walking_the_dog/75.mp4': 'taking_photos',
#   'walking_the_dog/33.mp4': 'writing_on_a_board',
#   'walking_the_dog/6.mp4': 'running',
#   'walking_the_dog/67.mp4': 'climbing',
#   'walking_the_dog/37.mp4': 'cleaning_the_floor',
#   'walking_the_dog/86.mp4': 'applauding',
#   'reading_book/42.mp4': 'writing_on_a_book',
#   'reading_book/79.mp4': 'writing_on_a_book',
#   'reading_book/78.mp4': 'playing_guitar',
#   'reading_book/76.mp4': 'writing_on_a_book',
#   'reading_book/45.mp4': 'watching_TV',
#   'reading_book/1.mp4': 'writing_on_a_board',
#   'reading_book/35.mp4': 'taking_photos',
#   'reading_book/40.mp4': 'looking_through_a_microscope',
#   'riding_or_walking_with_horse/17.mp4': 'shooting_an_arrow',
#   'riding_or_walking_with_horse/46.mp4': 'feeding_a_horse',
#   'riding_or_walking_with_horse/58.mp4': 'waving_hands',
#   'riding_or_walking_with_horse/84.mp4': 'running',
#   'riding_or_walking_with_horse/22.mp4': 'writing_on_a_board',
#   'using_computer/32.mp4': 'watching_TV',
#   'using_computer/5.mp4': 'writing_on_a_board',
#   'using_computer/33.mp4': 'pushing_a_cart',
#   'riding_a_bike/79.mp4': 'using_a_computer',
#   'riding_a_bike/20.mp4': 'climbing',
#   'riding_a_bike/74.mp4': 'texting_message',
#   'brushing_teeth/85.mp4': 'writing_on_a_board',
#   'brushing_teeth/44.mp4': 'writing_on_a_board',
#   'brushing_teeth/34.mp4': 'drinking',
#   'brushing_teeth/51.mp4': 'playing_guitar',
#   'brushing_teeth/56.mp4': 'writing_on_a_book',
#   'brushing_teeth/75.mp4': 'washing_dishes',
#   'brushing_teeth/52.mp4': 'reading',
#   'drinking_beer/30.mp4': 'applauding',
#   'drinking_beer/38.mp4': 'writing_on_a_board',
#   'drinking_beer/5.mp4': 'looking_through_a_microscope',
#   'drinking_beer/77.mp4': 'writing_on_a_board',
#   'drinking_beer/2.mp4': 'looking_through_a_microscope',
#   'drinking_beer/79.mp4': 'blowing_bubbles',
#   'drinking_beer/58.mp4': 'writing_on_a_board',
#   'drinking_beer/80.mp4': 'applauding',
#   'drinking_beer/85.mp4': 'cooking',
#   'drinking_beer/76.mp4': 'looking_through_a_telescope',
#   'drinking_beer/60.mp4': 'looking_through_a_microscope',
#   'drinking_beer/89.mp4': 'applauding',
#   'drinking_beer/48.mp4': 'pouring_liquid',
#   'drinking_beer/61.mp4': 'cleaning_the_floor',
#   'drinking_beer/11.mp4': 'feeding_a_horse',
#   'drinking_beer/59.mp4': 'writing_on_a_board',
#   'drinking_beer/7.mp4': 'watching_TV',
#   'drinking_beer/35.mp4': 'watching_TV',
#   'drinking_beer/31.mp4': 'applauding',
#   'drinking_beer/53.mp4': 'watching_TV',
#   'drinking_beer/9.mp4': 'watching_TV',
#   'drinking_beer/26.mp4': 'applauding',
#   'drinking_beer/84.mp4': 'watching_TV',
#   'drinking_beer/51.mp4': 'pouring_liquid',
#   'drinking_beer/56.mp4': 'smoking',
#   'drinking_beer/75.mp4': 'writing_on_a_board',
#   'drinking_beer/27.mp4': 'brushing_teeth',
#   'drinking_beer/21.mp4': 'taking_photos',
#   'drinking_beer/52.mp4': 'applauding',
#   'drinking_beer/33.mp4': 'pouring_liquid',
#   'drinking_beer/49.mp4': 'waving_hands',
#   'drinking_beer/37.mp4': 'applauding',
#   'cleaning_floor/57.mp4': 'looking_through_a_telescope',
#   'cleaning_floor/63.mp4': 'writing_on_a_board',
#   'cleaning_floor/12.mp4': 'writing_on_a_book',
#   'cleaning_floor/42.mp4': 'playing_violin',
#   'cleaning_floor/73.mp4': 'cutting_vegetables',
#   'cleaning_floor/81.mp4': 'pushing_a_cart',
#   'cleaning_floor/56.mp4': 'writing_on_a_board',
#   'cleaning_floor/90.mp4': 'applauding',
#   'cleaning_floor/91.mp4': 'looking_through_a_microscope',
#   'cleaning_floor/70.mp4': 'drinking',
#   'smoking/32.mp4': 'writing_on_a_board',
#   'smoking/54.mp4': 'writing_on_a_board',
#   'smoking/39.mp4': 'writing_on_a_board',
#   'smoking/55.mp4': 'taking_photos',
#   'smoking/14.mp4': 'drinking',
#   'smoking/76.mp4': 'applauding',
#   'smoking/64.mp4': 'applauding',
#   'smoking/61.mp4': 'writing_on_a_board',
#   'smoking/11.mp4': 'taking_photos',
#   'smoking/59.mp4': 'writing_on_a_board',
#   'smoking/44.mp4': 'applauding',
#   'smoking/22.mp4': 'playing_violin',
#   'smoking/27.mp4': 'brushing_teeth',
#   'smoking/10.mp4': 'waving_hands',
#   'smoking/74.mp4': 'writing_on_a_book',
#   'smoking/13.mp4': 'drinking',
#   'smoking/49.mp4': 'applauding',
#   'smoking/40.mp4': 'brushing_teeth',
#   'smoking/66.mp4': 'waving_hands',
#   'pushing_cart/58.mp4': 'cleaning_the_floor',
#   'pushing_cart/80.mp4': 'writing_on_a_board',
#   'pushing_cart/55.mp4': 'cleaning_the_floor',
#   'pushing_cart/76.mp4': 'cleaning_the_floor',
#   'pushing_cart/9.mp4': 'writing_on_a_board',
#   'pushing_cart/26.mp4': 'playing_violin',
#   'pushing_cart/75.mp4': 'writing_on_a_board',
#   'pushing_cart/23.mp4': 'watching_TV',
#   'pushing_cart/49.mp4': 'writing_on_a_board',
#   'pushing_cart/40.mp4': 'phoning',
#   'playing_guitar/46.mp4': 'writing_on_a_board',
#   'playing_guitar/31.mp4': 'brushing_teeth',
#   'playing_guitar/26.mp4': 'looking_through_a_telescope'}}

# %%
# Calculate percentages
total = 702 + 295 + 181
correct = 702 / total * 100
in_top_5 = (702 + 295) / total * 100

# %%
print("Classification Accuracy")
print("-----------------------")
print("Accuracy is:   {0:.2f} %".format(correct))

print("Top 5 acc is:  {0:.2f} %".format(in_top_5))
# Out:
# Classification Accuracy
# -----------------------
# Accuracy is:   59.59 %
# Top 5 acc is:  84.63 %

# %%
# Write results to file in case we need to analyze it in the future
with open("results.json", "w") as fp:
    json.dump(results, fp)
